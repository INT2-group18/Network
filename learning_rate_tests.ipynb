# %%
# Notes
# Batch size 32-128
# lr <= 0.0001 for relu
# if we want more data so training > test, can use data augmentation
# experimented with some dropout layers to prevent overfitting, low probability on conv layers, 0.4+ on fc layers
# relu, CrossEntropy and Adam seem to make most sense

# %%
import random

import torch, time, gc
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset
import matplotlib.pyplot as plt
import matplotlib.gridspec as grid

# Setup device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print(f'Using {torch.cuda.get_device_name(0)}')
SAVE_PATH = "./saves/neural_net.pth"

# Training variables
BATCH_SIZE = 32
EPOCHS = 60
LEARNING_RATE = 0.00009
learning_rate_testers = [0.0005, 0.0025, 0.00015, 0.0001, 0.00009, 0.00008, 0.00007, 0.00005, 0.000025, 0.00001, 0.0000075]
WEIGHT_DECAY = 0.0005

# Define the transforms for the dataset
transform = transforms.Compose([
    transforms.Resize(256, antialias=True),
    transforms.CenterCrop(256),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
augment_transform = transforms.Compose([
    transforms.Resize(256, antialias=True),
    transforms.CenterCrop(256),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    transforms.RandomApply(
        [transforms.RandomApply([transforms.RandomAffine(degrees=359, translate=(0.2, 0.2), shear=(20, 20, 20, 20)),
                                 transforms.RandomHorizontalFlip(1), transforms.RandomVerticalFlip(1)], p=0.7),
         transforms.ColorJitter(brightness=(0.75, 1.25), contrast=(0.75, 1.25), hue=(-0.15, 0.15),
                                saturation=(0.75, 1.25))
         ]
    )
])

val_accuracies, val_losses, train_accuracies, train_losses = [], [], [], []

# Load the train dataset
train_dataset = datasets.Flowers102(root="./data", split="train", transform=transform, download=True)
train_miniset = Subset(train_dataset, list(range(0, round(len(train_dataset)/2))))
all_train_data = [train_dataset]

# Since augment transform has probability/random changes, we can use it multiple times to generate more training data
for i in range(1):
    all_train_data.append(
        datasets.Flowers102(root="./data", split="train", transform=augment_transform, download=False))
train_dataset_extra = torch.utils.data.ConcatDataset(all_train_data)

train_loader = DataLoader(train_dataset_extra, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)

# Load validation dataset
val_dataset = datasets.Flowers102(root="./data", split="val", transform=transform, download=True)
# val_miniset = Subset(val_dataset, random_indexes)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

test_dataset = datasets.Flowers102(root="./data", split="test", transform=transform, download=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)


# Define the CNN architecture
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(32),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2, 2))  # 128
        self.conv2 = nn.Sequential(nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(64),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2, 2)) # 64
        self.conv3 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(64),
                                   nn.ReLU())
        self.conv4 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(64),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2, 2))  # 32
        self.conv5 = nn.Sequential(nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(128),
                                   nn.ReLU())
        self.conv6 = nn.Sequential(nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(128),
                                   nn.ReLU())
        self.conv7 = nn.Sequential(nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(128),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2, 2))  # 16
        self.conv8 = nn.Sequential(nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(256),
                                   nn.ReLU())
        self.conv9 = nn.Sequential(nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(256),
                                   nn.ReLU())
        self.conv10 = nn.Sequential(nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
                                    nn.BatchNorm2d(256),
                                    nn.ReLU(),
                                    nn.MaxPool2d(2, 2))  # 8
                                    # nn.Dropout(p=0.2))
        self.conv11 = nn.Sequential(nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
                                    nn.BatchNorm2d(512),
                                    nn.ReLU())
        self.conv12 = nn.Sequential(nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
                                    nn.BatchNorm2d(512),
                                    nn.ReLU())
        self.conv13 = nn.Sequential(nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
                                    nn.BatchNorm2d(512),
                                    nn.ReLU(),
                                    nn.MaxPool2d(2, 2))  # 4
                                    # nn.Dropout(p=0.2))
        self.fc1 = nn.Sequential(nn.Linear(4 * 4 * 512, 4096),
                                 nn.ReLU())
                                 # nn.Dropout(0.65))
        self.fc2 = nn.Sequential(nn.Linear(4096, 4096),
                                 nn.ReLU())
                                 # nn.Dropout(0.75))
        self.fc3 = nn.Sequential(nn.Linear(4096, 102))
        # Final output_features size must be 102 as there are 102 labels in the dataset
        # Pool dimensions: out=(in-kernel)/stride + 1

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = self.conv6(x)
        x = self.conv7(x)
        x = self.conv8(x)
        x = self.conv9(x)
        x = self.conv9(x)
        x = self.conv10(x)
        x = self.conv11(x)
        x = self.conv12(x)
        x = self.conv12(x)
        x = self.conv13(x)
        # x = self.conv6(x)
        # x = self.conv6(x)
        # x = self.conv7(x)
        # x = self.conv8(x)
        # x = self.conv9(x)
        # x = self.conv10(x)
        # x = self.conv11(x)
        # x = self.conv12(x)
        # x = self.conv13(x)
        # x = self.conv14(x)
        x = x.view(-1, 4 * 4 * 512)
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        return x
        # Final output_features size must be 102 as there are 102 labels in the dataset
        # Pool dimensions: out=(in-kernel)/stride + 1

# %%
def train_one_epoch(net: nn.Module = None, training_loss: [] = None, training_acc: [] = None, optimizer=None, lr: float = LEARNING_RATE):
    if optimizer is None:
        optimizer = optim.AdamW(net.parameters(), lr=lr)

    net.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (images, labels) in enumerate(train_loader):
        labels = torch.eye(102)[labels]  # one hot encode
        images = images.to(device)
        labels = labels.to(device)

        outputs = net(images)  # train
        labels = torch.argmax(labels, dim=1)  # one hot decode

        loss = criterion(outputs, labels)
        running_loss += loss.item() * images.size(0)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += torch.sum(predicted == labels).sum().item()

    running_loss /= len(all_train_data)
    train_accuracy = 100 * correct / total
    # save data
    training_loss.append(running_loss)
    training_acc.append(train_accuracy)
    print(f'Training Loss: {running_loss:.4f}, Accuracy: {train_accuracy:.2f}%')
    return training_loss, training_acc

# %%
def validate_one_epoch(net: nn.Module = None, valid_loss: [] = None, valid_acc: [] = None):
    net.eval()
    with torch.no_grad():
        running_vloss = 0.0
        vcorrect = 0
        vtotal = 0
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = net(images)
            vloss = criterion(outputs, labels)
            running_vloss += vloss.item() * images.size(0)

            _, predicted = torch.max(outputs.data, 1)
            vtotal += labels.size(0)
            vcorrect += (predicted == labels).sum().item()

        vaccuracy = 100 * vcorrect / vtotal

        # save validation data
        valid_loss.append(running_vloss)
        valid_acc.append(vaccuracy)
        print(f'Validation Loss: {running_vloss:.4f}, Accuracy: {vaccuracy:.2f}%')
        return valid_loss, valid_acc

# %%
def train_net(net: nn.Module = None, epochs: int = 1, validation_loss=None, validation_accuracy=None,
              training_loss=None, training_accuracy=None, epochs_already_trained: int = 0, lr: float = LEARNING_RATE):
    optimizer = optim.AdamW(cnn.parameters(), lr=lr)

    if training_accuracy is None:
        training_accuracy = []
    if training_loss is None:
        training_loss = []
    if validation_accuracy is None:
        validation_accuracy = []
    if validation_loss is None:
        validation_loss = []

    epochs += epochs_already_trained
    for epoch in range(epochs_already_trained, epochs):
        print(f'Epoch: [{epoch + 1}/{epochs}]')

        training_loss, training_accuracy = train_one_epoch(net, training_loss=training_loss,
                                                           training_acc=training_accuracy, optimizer=optimizer)
        # validation_loss, validation_accuracy = validate_one_epoch(net, valid_loss=validation_loss,
        #                                                           valid_acc=validation_accuracy)
        torch.save(net.state_dict(), SAVE_PATH)
        with open("./saves/save_data.txt", "w") as savefile:
            # savefile.writelines(str(validation_loss))
            # savefile.writelines(str(validation_accuracy))
            savefile.writelines(str(training_loss))
            savefile.writelines(str(training_accuracy))
            savefile.write(str(epoch + 1))
        print("NN saved.")

# %%
def train_net_from_save(epochs: int = 1, save_folder_path: str = "./saves"):
    print("Resuming training from save.")
    net = CNN().to(device)
    net.load_state_dict(torch.load(save_folder_path + "/neural_net.pth"))
    with open(save_folder_path + "/save_data.txt", "r") as savefile:
        savelist = savefile.readline().split("]")
        v_losses, v_accs, t_losses, t_accs = [], [], [], []
        # for vloss in savelist[0][1::].split(","):
        #     v_losses.append(float(vloss.strip()))
        # for vacc in savelist[1][1::].split(","):
            # v_accs.append(float(vacc.strip()))
        for tloss in savelist[2][1::].split(","):
            t_losses.append(float(tloss.strip()))
        for tacc in savelist[3][1::].split(","):
            t_accs.append(float(tacc.strip()))
        epochs_done = int(savelist[4])
    print("Net loaded. " + str(epochs_done) + " epochs previously trained.")
    train_net(net=net, epochs=epochs, validation_loss=v_losses, validation_accuracy=v_accs, training_accuracy=t_accs,
              training_loss=t_losses, epochs_already_trained=epochs_done)

# %%
def test_net(net: nn.Module = None):
    if net is None:
        try:
            net = CNN().to(device)
            net.load_state_dict(torch.load("./saves/neural_net.pth"))
        except:
            return
    net.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            # pred_labels = torch.argmax(outputs, axis=1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        print(f"Test Accuracy: {(100 * correct / total):.2f}%")

# %%
def test_net_from_save(save_folder_path: str = "./saves"):
    net = CNN().to(device)
    net.load_state_dict(torch.load(save_folder_path + "/neural_net.pth"))
    test_net(net)

# %%
# Clear cuda cache
gc.collect()
torch.cuda.empty_cache()

# Create an instance of the CNN and move it to the device
cnn = CNN().to(device)
print(cnn)

# Define the loss function and the optimizer
criterion = nn.CrossEntropyLoss()
# Out:
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv4): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv6): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv7): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv8): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv9): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv10): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv11): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv12): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv13): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=8192, out_features=4096, bias=True)
#     (1): ReLU()
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=4096, out_features=4096, bias=True)
#     (1): ReLU()
#   )
#   (fc3): Sequential(
#     (0): Linear(in_features=4096, out_features=102, bias=True)
#   )
# )

# %%
all_t_losses = []
all_t_accs = []

for i in learning_rate_testers:
  cnn = CNN().to(device)
  print(f"Starting training with lr: {i}")
  # Start timer
  start_time = time.time()

  train_net(cnn, EPOCHS)

  # Stop timer
  end_time = time.time()
  print("Training Complete in: " + time.strftime("%Hh %Mm %Ss", time.gmtime(end_time - start_time)))

  with open("./saves/save_data.txt", "r") as savefile:
    savelist = savefile.readline().split("]")
    t_losses, t_accs = [], []
    for tloss in savelist[0][1::].split(","):
        t_losses.append(float(tloss.strip()))
    all_t_losses.append(t_losses)
    for tacc in savelist[1][1::].split(","):
        t_accs.append(float(tacc.strip()))
    all_t_accs.append(t_accs)
# Out:
# Starting training with lr: 0.0005
# Epoch: [1/60]
# Training Loss: 4632.0930, Accuracy: 2.11%
# NN saved.
# Epoch: [2/60]
# Training Loss: 4204.8344, Accuracy: 4.61%
# NN saved.
# Epoch: [3/60]
# Training Loss: 3848.0438, Accuracy: 7.84%
# NN saved.
# Epoch: [4/60]
# Training Loss: 3512.2365, Accuracy: 13.14%
# NN saved.
# Epoch: [5/60]
# Training Loss: 3188.7316, Accuracy: 19.80%
# NN saved.
# Epoch: [6/60]
# Training Loss: 2804.4747, Accuracy: 27.40%
# NN saved.
# Epoch: [7/60]
# Training Loss: 2534.1197, Accuracy: 33.48%
# NN saved.
# Epoch: [8/60]
# Training Loss: 2193.3904, Accuracy: 42.94%
# NN saved.
# Epoch: [9/60]
# Training Loss: 1824.6258, Accuracy: 53.48%
# NN saved.
# Epoch: [10/60]
# Training Loss: 1602.1766, Accuracy: 57.79%
# NN saved.
# Epoch: [11/60]
# Training Loss: 1394.4559, Accuracy: 64.17%
# NN saved.
# Epoch: [12/60]
# Training Loss: 1235.1563, Accuracy: 70.39%
# NN saved.
# Epoch: [13/60]
# Training Loss: 1127.6849, Accuracy: 72.79%
# NN saved.
# Epoch: [14/60]
# Training Loss: 1033.4573, Accuracy: 75.88%
# NN saved.
# Epoch: [15/60]
# Training Loss: 1061.3314, Accuracy: 74.66%
# NN saved.
# Epoch: [16/60]
# Training Loss: 908.5928, Accuracy: 78.28%
# NN saved.
# Epoch: [17/60]
# Training Loss: 828.7067, Accuracy: 80.29%
# NN saved.
# Epoch: [18/60]
# Training Loss: 877.8819, Accuracy: 79.95%
# NN saved.
# Epoch: [19/60]
# Training Loss: 814.3774, Accuracy: 81.52%
# NN saved.
# Epoch: [20/60]
# Training Loss: 781.3881, Accuracy: 80.83%
# NN saved.
# Epoch: [21/60]
# Training Loss: 860.0914, Accuracy: 79.71%
# NN saved.
# Epoch: [22/60]
# Training Loss: 745.9356, Accuracy: 82.70%
# NN saved.
# Epoch: [23/60]
# Training Loss: 740.5254, Accuracy: 82.35%
# NN saved.
# Epoch: [24/60]
# Training Loss: 771.2237, Accuracy: 81.76%
# NN saved.
# Epoch: [25/60]
# Training Loss: 799.2919, Accuracy: 81.32%
# NN saved.
# Epoch: [26/60]
# Training Loss: 820.2843, Accuracy: 80.64%
# NN saved.
# Epoch: [27/60]
# Training Loss: 715.4543, Accuracy: 82.50%
# NN saved.
# Epoch: [28/60]
# Training Loss: 729.9379, Accuracy: 83.48%
# NN saved.
# Epoch: [29/60]
# Training Loss: 638.9884, Accuracy: 84.90%
# NN saved.
# Epoch: [30/60]
# Training Loss: 723.8394, Accuracy: 82.45%
# NN saved.
# Epoch: [31/60]
# Training Loss: 656.3851, Accuracy: 84.36%
# NN saved.
# Epoch: [32/60]
# Training Loss: 654.3264, Accuracy: 84.36%
# NN saved.
# Epoch: [33/60]
# Training Loss: 652.9273, Accuracy: 84.75%
# NN saved.
# Epoch: [34/60]
# Training Loss: 686.5341, Accuracy: 83.33%
# NN saved.
# Epoch: [35/60]
# Training Loss: 678.7891, Accuracy: 83.53%
# NN saved.
# Epoch: [36/60]
# Training Loss: 703.9350, Accuracy: 82.50%
# NN saved.
# Epoch: [37/60]
# Training Loss: 708.2136, Accuracy: 82.65%
# NN saved.
# Epoch: [38/60]
# Training Loss: 657.5806, Accuracy: 84.12%
# NN saved.
# Epoch: [39/60]
# Training Loss: 639.7814, Accuracy: 84.22%
# NN saved.
# Epoch: [40/60]
# Training Loss: 615.5558, Accuracy: 84.56%
# NN saved.
# Epoch: [41/60]
# Training Loss: 631.5543, Accuracy: 84.66%
# NN saved.
# Epoch: [42/60]
# Training Loss: 614.9345, Accuracy: 84.95%
# NN saved.
# Epoch: [43/60]
# Training Loss: 604.5329, Accuracy: 85.39%
# NN saved.
# Epoch: [44/60]
# Training Loss: 617.4998, Accuracy: 85.29%
# NN saved.
# Epoch: [45/60]
# Training Loss: 610.8564, Accuracy: 85.64%
# NN saved.
# Epoch: [46/60]
# Training Loss: 601.5426, Accuracy: 84.95%
# NN saved.
# Epoch: [47/60]
# Training Loss: 603.5364, Accuracy: 85.05%
# NN saved.
# Epoch: [48/60]
# Training Loss: 631.9186, Accuracy: 83.63%
# NN saved.
# Epoch: [49/60]
# Training Loss: 535.5458, Accuracy: 86.86%
# NN saved.
# Epoch: [50/60]
# Training Loss: 582.1886, Accuracy: 85.34%
# NN saved.
# Epoch: [51/60]
# Training Loss: 501.5906, Accuracy: 86.86%
# NN saved.
# Epoch: [52/60]
# Training Loss: 613.4891, Accuracy: 84.36%
# NN saved.
# Epoch: [53/60]
# Training Loss: 582.0219, Accuracy: 85.88%
# NN saved.
# Epoch: [54/60]
# Training Loss: 572.6342, Accuracy: 85.64%
# NN saved.
# Epoch: [55/60]
# Training Loss: 533.7277, Accuracy: 85.93%
# NN saved.
# Epoch: [56/60]
# Training Loss: 530.5283, Accuracy: 86.23%
# NN saved.
# Epoch: [57/60]
# Training Loss: 541.3232, Accuracy: 86.27%
# NN saved.
# Epoch: [58/60]
# Training Loss: 518.6506, Accuracy: 87.01%
# NN saved.
# Epoch: [59/60]
# Training Loss: 497.1743, Accuracy: 87.35%
# NN saved.
# Epoch: [60/60]
# Training Loss: 549.9740, Accuracy: 85.29%
# NN saved.
# Training Complete in: 00h 19m 20s
# Starting training with lr: 0.0025
# Epoch: [1/60]
# Training Loss: 4740.8523, Accuracy: 1.52%
# NN saved.
# Epoch: [2/60]
# Training Loss: 4487.0448, Accuracy: 2.25%
# NN saved.
# Epoch: [3/60]
# Training Loss: 4095.3594, Accuracy: 5.44%
# NN saved.
# Epoch: [4/60]
# Training Loss: 3713.5887, Accuracy: 10.00%
# NN saved.
# Epoch: [5/60]
# Training Loss: 3501.6996, Accuracy: 13.53%
# NN saved.
# Epoch: [6/60]
# Training Loss: 3189.5028, Accuracy: 18.97%
# NN saved.
# Epoch: [7/60]
# Training Loss: 2881.9346, Accuracy: 26.72%
# NN saved.
# Epoch: [8/60]
# Training Loss: 2516.2121, Accuracy: 34.85%
# NN saved.
# Epoch: [9/60]
# Training Loss: 2206.1144, Accuracy: 41.37%
# NN saved.
# Epoch: [10/60]
# Training Loss: 1981.6208, Accuracy: 49.07%
# NN saved.
# Epoch: [11/60]
# Training Loss: 1689.7311, Accuracy: 56.27%
# NN saved.
# Epoch: [12/60]
# Training Loss: 1482.9926, Accuracy: 63.87%
# NN saved.
# Epoch: [13/60]
# Training Loss: 1249.4612, Accuracy: 70.20%
# NN saved.
# Epoch: [14/60]
# Training Loss: 1131.0347, Accuracy: 73.09%
# NN saved.
# Epoch: [15/60]
# Training Loss: 1052.6115, Accuracy: 75.29%
# NN saved.
# Epoch: [16/60]
# Training Loss: 1007.6916, Accuracy: 76.23%
# NN saved.
# Epoch: [17/60]
# Training Loss: 918.4212, Accuracy: 78.58%
# NN saved.
# Epoch: [18/60]
# Training Loss: 919.5976, Accuracy: 79.41%
# NN saved.
# Epoch: [19/60]
# Training Loss: 917.3565, Accuracy: 78.82%
# NN saved.
# Epoch: [20/60]
# Training Loss: 904.3757, Accuracy: 78.28%
# NN saved.
# Epoch: [21/60]
# Training Loss: 864.5341, Accuracy: 79.85%
# NN saved.
# Epoch: [22/60]
# Training Loss: 906.4813, Accuracy: 78.63%
# NN saved.
# Epoch: [23/60]
# Training Loss: 860.3169, Accuracy: 79.90%
# NN saved.
# Epoch: [24/60]
# Training Loss: 779.9764, Accuracy: 81.08%
# NN saved.
# Epoch: [25/60]
# Training Loss: 853.8374, Accuracy: 79.51%
# NN saved.
# Epoch: [26/60]
# Training Loss: 775.2915, Accuracy: 81.13%
# NN saved.
# Epoch: [27/60]
# Training Loss: 708.0287, Accuracy: 83.38%
# NN saved.
# Epoch: [28/60]
# Training Loss: 734.7814, Accuracy: 82.79%
# NN saved.
# Epoch: [29/60]
# Training Loss: 801.6686, Accuracy: 82.06%
# NN saved.
# Epoch: [30/60]
# Training Loss: 719.4215, Accuracy: 82.50%
# NN saved.
# Epoch: [31/60]
# Training Loss: 797.6314, Accuracy: 80.69%
# NN saved.
# Epoch: [32/60]
# Training Loss: 910.9297, Accuracy: 78.38%
# NN saved.
# Epoch: [33/60]
# Training Loss: 744.5431, Accuracy: 81.57%
# NN saved.
# Epoch: [34/60]
# Training Loss: 701.4149, Accuracy: 83.14%
# NN saved.
# Epoch: [35/60]
# Training Loss: 723.7524, Accuracy: 82.60%
# NN saved.
# Epoch: [36/60]
# Training Loss: 692.8569, Accuracy: 83.68%
# NN saved.
# Epoch: [37/60]
# Training Loss: 695.0294, Accuracy: 83.48%
# NN saved.
# Epoch: [38/60]
# Training Loss: 733.4303, Accuracy: 82.01%
# NN saved.
# Epoch: [39/60]
# Training Loss: 715.3573, Accuracy: 82.65%
# NN saved.
# Epoch: [40/60]
# Training Loss: 688.8798, Accuracy: 82.75%
# NN saved.
# Epoch: [41/60]
# Training Loss: 672.4363, Accuracy: 83.92%
# NN saved.
# Epoch: [42/60]
# Training Loss: 670.7706, Accuracy: 83.43%
# NN saved.
# Epoch: [43/60]
# Training Loss: 647.3224, Accuracy: 84.80%
# NN saved.
# Epoch: [44/60]
# Training Loss: 664.1855, Accuracy: 83.87%
# NN saved.
# Epoch: [45/60]
# Training Loss: 633.3607, Accuracy: 84.56%
# NN saved.
# Epoch: [46/60]
# Training Loss: 665.0018, Accuracy: 84.56%
# NN saved.
# Epoch: [47/60]
# Training Loss: 665.2521, Accuracy: 83.68%
# NN saved.
# Epoch: [48/60]
# Training Loss: 601.1977, Accuracy: 85.44%
# NN saved.
# Epoch: [49/60]
# Training Loss: 624.4152, Accuracy: 84.31%
# NN saved.
# Epoch: [50/60]
# Training Loss: 688.6205, Accuracy: 83.24%
# NN saved.
# Epoch: [51/60]
# Training Loss: 578.2649, Accuracy: 85.74%
# NN saved.
# Epoch: [52/60]
# Training Loss: 598.6837, Accuracy: 85.05%
# NN saved.
# Epoch: [53/60]
# Training Loss: 614.8405, Accuracy: 84.85%
# NN saved.
# Epoch: [54/60]
# Training Loss: 579.7044, Accuracy: 84.95%
# NN saved.
# Epoch: [55/60]
# Training Loss: 568.9672, Accuracy: 86.03%
# NN saved.
# Epoch: [56/60]
# Training Loss: 625.7760, Accuracy: 84.36%
# NN saved.
# Epoch: [57/60]
# Training Loss: 587.3194, Accuracy: 85.64%
# NN saved.
# Epoch: [58/60]
# Training Loss: 653.0794, Accuracy: 83.14%
# NN saved.
# Epoch: [59/60]
# Training Loss: 581.2685, Accuracy: 85.25%
# NN saved.
# Epoch: [60/60]
# Training Loss: 545.3672, Accuracy: 86.03%
# NN saved.
# Training Complete in: 00h 20m 24s
# Starting training with lr: 0.00015
# Epoch: [1/60]
# Training Loss: 4677.4184, Accuracy: 1.52%
# NN saved.
# Epoch: [2/60]
# Training Loss: 4240.0431, Accuracy: 4.36%
# NN saved.
# Epoch: [3/60]
# Training Loss: 3911.9174, Accuracy: 6.81%
# NN saved.
# Epoch: [4/60]
# Training Loss: 3647.6427, Accuracy: 10.74%
# NN saved.
# Epoch: [5/60]
# Training Loss: 3299.6853, Accuracy: 16.08%
# NN saved.
# Epoch: [6/60]
# Training Loss: 3065.5927, Accuracy: 21.52%
# NN saved.
# Epoch: [7/60]
# Training Loss: 2740.7877, Accuracy: 28.82%
# NN saved.
# Epoch: [8/60]
# Training Loss: 2319.2723, Accuracy: 39.26%
# NN saved.
# Epoch: [9/60]
# Training Loss: 2003.5634, Accuracy: 46.86%
# NN saved.
# Epoch: [10/60]
# Training Loss: 1621.5482, Accuracy: 58.92%
# NN saved.
# Epoch: [11/60]
# Training Loss: 1428.2004, Accuracy: 65.34%
# NN saved.
# Epoch: [12/60]
# Training Loss: 1322.4768, Accuracy: 67.40%
# NN saved.
# Epoch: [13/60]
# Training Loss: 1067.1892, Accuracy: 74.31%
# NN saved.
# Epoch: [14/60]
# Training Loss: 1057.6108, Accuracy: 75.88%
# NN saved.
# Epoch: [15/60]
# Training Loss: 924.4660, Accuracy: 78.09%
# NN saved.
# Epoch: [16/60]
# Training Loss: 909.8050, Accuracy: 78.53%
# NN saved.
# Epoch: [17/60]
# Training Loss: 835.9219, Accuracy: 80.29%
# NN saved.
# Epoch: [18/60]
# Training Loss: 851.6842, Accuracy: 80.25%
# NN saved.
# Epoch: [19/60]
# Training Loss: 820.7695, Accuracy: 80.78%
# NN saved.
# Epoch: [20/60]
# Training Loss: 811.2992, Accuracy: 81.23%
# NN saved.
# Epoch: [21/60]
# Training Loss: 801.9006, Accuracy: 80.93%
# NN saved.
# Epoch: [22/60]
# Training Loss: 727.8692, Accuracy: 82.45%
# NN saved.
# Epoch: [23/60]
# Training Loss: 714.4827, Accuracy: 83.09%
# NN saved.
# Epoch: [24/60]
# Training Loss: 729.3411, Accuracy: 82.25%
# NN saved.
# Epoch: [25/60]
# Training Loss: 729.9894, Accuracy: 82.35%
# NN saved.
# Epoch: [26/60]
# Training Loss: 766.3876, Accuracy: 81.62%
# NN saved.
# Epoch: [27/60]
# Training Loss: 698.4890, Accuracy: 83.28%
# NN saved.
# Epoch: [28/60]
# Training Loss: 681.1777, Accuracy: 82.79%
# NN saved.
# Epoch: [29/60]
# Training Loss: 724.3475, Accuracy: 83.04%
# NN saved.
# Epoch: [30/60]
# Training Loss: 661.1803, Accuracy: 84.46%
# NN saved.
# Epoch: [31/60]
# Training Loss: 668.8253, Accuracy: 83.92%
# NN saved.
# Epoch: [32/60]
# Training Loss: 648.2430, Accuracy: 83.92%
# NN saved.
# Epoch: [33/60]
# Training Loss: 682.1791, Accuracy: 83.09%
# NN saved.
# Epoch: [34/60]
# Training Loss: 636.3275, Accuracy: 85.10%
# NN saved.
# Epoch: [35/60]
# Training Loss: 707.7722, Accuracy: 82.99%
# NN saved.
# Epoch: [36/60]
# Training Loss: 635.6784, Accuracy: 84.71%
# NN saved.
# Epoch: [37/60]
# Training Loss: 607.2139, Accuracy: 84.90%
# NN saved.
# Epoch: [38/60]
# Training Loss: 607.1430, Accuracy: 84.66%
# NN saved.
# Epoch: [39/60]
# Training Loss: 639.0418, Accuracy: 84.22%
# NN saved.
# Epoch: [40/60]
# Training Loss: 650.8189, Accuracy: 84.17%
# NN saved.
# Epoch: [41/60]
# Training Loss: 613.9505, Accuracy: 85.34%
# NN saved.
# Epoch: [42/60]
# Training Loss: 601.4783, Accuracy: 84.75%
# NN saved.
# Epoch: [43/60]
# Training Loss: 631.0600, Accuracy: 85.15%
# NN saved.
# Epoch: [44/60]
# Training Loss: 592.6344, Accuracy: 85.59%
# NN saved.
# Epoch: [45/60]
# Training Loss: 607.4263, Accuracy: 84.56%
# NN saved.
# Epoch: [46/60]
# Training Loss: 624.8662, Accuracy: 84.61%
# NN saved.
# Epoch: [47/60]
# Training Loss: 580.0779, Accuracy: 84.75%
# NN saved.
# Epoch: [48/60]
# Training Loss: 544.8488, Accuracy: 86.13%
# NN saved.
# Epoch: [49/60]
# Training Loss: 600.7334, Accuracy: 84.80%
# NN saved.
# Epoch: [50/60]
# Training Loss: 610.2558, Accuracy: 84.51%
# NN saved.
# Epoch: [51/60]
# Training Loss: 499.3096, Accuracy: 87.65%
# NN saved.
# Epoch: [52/60]
# Training Loss: 526.9955, Accuracy: 86.72%
# NN saved.
# Epoch: [53/60]
# Training Loss: 531.1183, Accuracy: 86.32%
# NN saved.
# Epoch: [54/60]
# Training Loss: 548.7395, Accuracy: 85.98%
# NN saved.
# Epoch: [55/60]
# Training Loss: 526.7135, Accuracy: 86.57%
# NN saved.
# Epoch: [56/60]
# Training Loss: 511.1175, Accuracy: 86.86%
# NN saved.
# Epoch: [57/60]
# Training Loss: 534.7535, Accuracy: 86.13%
# NN saved.
# Epoch: [58/60]
# Training Loss: 528.6054, Accuracy: 85.88%
# NN saved.
# Epoch: [59/60]
# Training Loss: 564.3761, Accuracy: 85.83%
# NN saved.
# Epoch: [60/60]
# Training Loss: 516.0061, Accuracy: 86.27%
# NN saved.
# Training Complete in: 00h 20m 08s
# Starting training with lr: 0.0001
# Epoch: [1/60]
# Training Loss: 4710.1505, Accuracy: 1.13%
# NN saved.
# Epoch: [2/60]
# Training Loss: 4429.3852, Accuracy: 2.45%
# NN saved.
# Epoch: [3/60]
# Training Loss: 3985.9126, Accuracy: 6.62%
# NN saved.
# Epoch: [4/60]
# Training Loss: 3635.0943, Accuracy: 10.88%
# NN saved.
# Epoch: [5/60]
# Training Loss: 3370.8813, Accuracy: 15.78%
# NN saved.
# Epoch: [6/60]
# Training Loss: 2985.7584, Accuracy: 22.75%
# NN saved.
# Epoch: [7/60]
# Training Loss: 2747.0493, Accuracy: 29.36%
# NN saved.
# Epoch: [8/60]
# Training Loss: 2486.3075, Accuracy: 35.10%
# NN saved.
# Epoch: [9/60]
# Training Loss: 2146.5688, Accuracy: 43.48%
# NN saved.
# Epoch: [10/60]
# Training Loss: 1936.5326, Accuracy: 49.71%
# NN saved.
# Epoch: [11/60]
# Training Loss: 1691.6776, Accuracy: 56.42%
# NN saved.
# Epoch: [12/60]
# Training Loss: 1454.4656, Accuracy: 63.33%
# NN saved.
# Epoch: [13/60]
# Training Loss: 1285.9754, Accuracy: 68.48%
# NN saved.
# Epoch: [14/60]
# Training Loss: 1093.7813, Accuracy: 75.25%
# NN saved.
# Epoch: [15/60]
# Training Loss: 1053.0997, Accuracy: 75.69%
# NN saved.
# Epoch: [16/60]
# Training Loss: 966.4249, Accuracy: 78.04%
# NN saved.
# Epoch: [17/60]
# Training Loss: 963.5160, Accuracy: 77.40%
# NN saved.
# Epoch: [18/60]
# Training Loss: 940.7095, Accuracy: 78.48%
# NN saved.
# Epoch: [19/60]
# Training Loss: 871.0591, Accuracy: 79.46%
# NN saved.
# Epoch: [20/60]
# Training Loss: 823.5176, Accuracy: 81.32%
# NN saved.
# Epoch: [21/60]
# Training Loss: 841.2483, Accuracy: 80.98%
# NN saved.
# Epoch: [22/60]
# Training Loss: 849.8547, Accuracy: 80.69%
# NN saved.
# Epoch: [23/60]
# Training Loss: 819.8491, Accuracy: 80.88%
# NN saved.
# Epoch: [24/60]
# Training Loss: 807.4824, Accuracy: 80.98%
# NN saved.
# Epoch: [25/60]
# Training Loss: 777.0465, Accuracy: 81.27%
# NN saved.
# Epoch: [26/60]
# Training Loss: 745.0824, Accuracy: 82.11%
# NN saved.
# Epoch: [27/60]
# Training Loss: 805.6282, Accuracy: 80.93%
# NN saved.
# Epoch: [28/60]
# Training Loss: 707.1181, Accuracy: 83.77%
# NN saved.
# Epoch: [29/60]
# Training Loss: 743.7979, Accuracy: 82.65%
# NN saved.
# Epoch: [30/60]
# Training Loss: 716.6810, Accuracy: 82.94%
# NN saved.
# Epoch: [31/60]
# Training Loss: 670.4058, Accuracy: 84.12%
# NN saved.
# Epoch: [32/60]
# Training Loss: 768.1681, Accuracy: 82.16%
# NN saved.
# Epoch: [33/60]
# Training Loss: 733.3632, Accuracy: 81.62%
# NN saved.
# Epoch: [34/60]
# Training Loss: 732.5992, Accuracy: 81.72%
# NN saved.
# Epoch: [35/60]
# Training Loss: 725.3729, Accuracy: 83.09%
# NN saved.
# Epoch: [36/60]
# Training Loss: 683.7915, Accuracy: 83.63%
# NN saved.
# Epoch: [37/60]
# Training Loss: 658.7356, Accuracy: 83.92%
# NN saved.
# Epoch: [38/60]
# Training Loss: 670.3212, Accuracy: 83.58%
# NN saved.
# Epoch: [39/60]
# Training Loss: 635.6349, Accuracy: 84.71%
# NN saved.
# Epoch: [40/60]
# Training Loss: 667.7985, Accuracy: 83.24%
# NN saved.
# Epoch: [41/60]
# Training Loss: 553.8318, Accuracy: 86.23%
# NN saved.
# Epoch: [42/60]
# Training Loss: 643.9760, Accuracy: 84.17%
# NN saved.
# Epoch: [43/60]
# Training Loss: 625.9684, Accuracy: 84.85%
# NN saved.
# Epoch: [44/60]
# Training Loss: 629.4633, Accuracy: 83.87%
# NN saved.
# Epoch: [45/60]
# Training Loss: 657.9851, Accuracy: 83.28%
# NN saved.
# Epoch: [46/60]
# Training Loss: 583.5294, Accuracy: 85.10%
# NN saved.
# Epoch: [47/60]
# Training Loss: 609.4178, Accuracy: 85.20%
# NN saved.
# Epoch: [48/60]
# Training Loss: 582.2409, Accuracy: 85.05%
# NN saved.
# Epoch: [49/60]
# Training Loss: 549.8982, Accuracy: 86.62%
# NN saved.
# Epoch: [50/60]
# Training Loss: 600.9529, Accuracy: 85.29%
# NN saved.
# Epoch: [51/60]
# Training Loss: 559.3486, Accuracy: 86.23%
# NN saved.
# Epoch: [52/60]
# Training Loss: 571.5237, Accuracy: 85.59%
# NN saved.
# Epoch: [53/60]
# Training Loss: 589.1858, Accuracy: 85.25%
# NN saved.
# Epoch: [54/60]
# Training Loss: 569.2840, Accuracy: 85.49%
# NN saved.
# Epoch: [55/60]
# Training Loss: 563.6330, Accuracy: 85.74%
# NN saved.
# Epoch: [56/60]
# Training Loss: 548.4360, Accuracy: 86.91%
# NN saved.
# Epoch: [57/60]
# Training Loss: 597.4112, Accuracy: 85.29%
# NN saved.
# Epoch: [58/60]
# Training Loss: 548.6234, Accuracy: 86.13%
# NN saved.
# Epoch: [59/60]
# Training Loss: 579.5907, Accuracy: 85.10%
# NN saved.
# Epoch: [60/60]
# Training Loss: 560.4094, Accuracy: 85.69%
# NN saved.
# Training Complete in: 00h 20m 11s
# Starting training with lr: 9e-05
# Epoch: [1/60]
# Training Loss: 4690.3919, Accuracy: 1.62%
# NN saved.
# Epoch: [2/60]
# Training Loss: 4284.7758, Accuracy: 4.41%
# NN saved.
# Epoch: [3/60]
# Training Loss: 3922.4286, Accuracy: 7.55%
# NN saved.
# Epoch: [4/60]
# Training Loss: 3680.8174, Accuracy: 10.69%
# NN saved.
# Epoch: [5/60]
# Training Loss: 3427.1200, Accuracy: 14.07%
# NN saved.
# Epoch: [6/60]
# Training Loss: 3122.5280, Accuracy: 21.08%
# NN saved.
# Epoch: [7/60]
# Training Loss: 2886.9976, Accuracy: 26.03%
# NN saved.
# Epoch: [8/60]
# Training Loss: 2537.0508, Accuracy: 34.12%
# NN saved.
# Epoch: [9/60]
# Training Loss: 2341.9237, Accuracy: 39.31%
# NN saved.
# Epoch: [10/60]
# Training Loss: 2049.5421, Accuracy: 47.50%
# NN saved.
# Epoch: [11/60]
# Training Loss: 1787.0723, Accuracy: 55.15%
# NN saved.
# Epoch: [12/60]
# Training Loss: 1584.8435, Accuracy: 60.83%
# NN saved.
# Epoch: [13/60]
# Training Loss: 1370.3286, Accuracy: 66.32%
# NN saved.
# Epoch: [14/60]
# Training Loss: 1201.5690, Accuracy: 70.20%
# NN saved.
# Epoch: [15/60]
# Training Loss: 1053.0557, Accuracy: 76.13%
# NN saved.
# Epoch: [16/60]
# Training Loss: 1013.8847, Accuracy: 76.32%
# NN saved.
# Epoch: [17/60]
# Training Loss: 950.6285, Accuracy: 78.53%
# NN saved.
# Epoch: [18/60]
# Training Loss: 976.6666, Accuracy: 77.75%
# NN saved.
# Epoch: [19/60]
# Training Loss: 951.4500, Accuracy: 78.19%
# NN saved.
# Epoch: [20/60]
# Training Loss: 846.5416, Accuracy: 80.88%
# NN saved.
# Epoch: [21/60]
# Training Loss: 874.7317, Accuracy: 79.85%
# NN saved.
# Epoch: [22/60]
# Training Loss: 925.0133, Accuracy: 79.17%
# NN saved.
# Epoch: [23/60]
# Training Loss: 812.7025, Accuracy: 81.67%
# NN saved.
# Epoch: [24/60]
# Training Loss: 761.3589, Accuracy: 82.65%
# NN saved.
# Epoch: [25/60]
# Training Loss: 796.9397, Accuracy: 81.18%
# NN saved.
# Epoch: [26/60]
# Training Loss: 783.8297, Accuracy: 81.52%
# NN saved.
# Epoch: [27/60]
# Training Loss: 799.1749, Accuracy: 81.57%
# NN saved.
# Epoch: [28/60]
# Training Loss: 766.5024, Accuracy: 81.37%
# NN saved.
# Epoch: [29/60]
# Training Loss: 795.6054, Accuracy: 81.03%
# NN saved.
# Epoch: [30/60]
# Training Loss: 664.1529, Accuracy: 84.75%
# NN saved.
# Epoch: [31/60]
# Training Loss: 708.6220, Accuracy: 83.68%
# NN saved.
# Epoch: [32/60]
# Training Loss: 765.2539, Accuracy: 81.57%
# NN saved.
# Epoch: [33/60]
# Training Loss: 723.8776, Accuracy: 83.04%
# NN saved.
# Epoch: [34/60]
# Training Loss: 779.7712, Accuracy: 81.67%
# NN saved.
# Epoch: [35/60]
# Training Loss: 726.0543, Accuracy: 82.11%
# NN saved.
# Epoch: [36/60]
# Training Loss: 678.5544, Accuracy: 84.02%
# NN saved.
# Epoch: [37/60]
# Training Loss: 725.6814, Accuracy: 82.21%
# NN saved.
# Epoch: [38/60]
# Training Loss: 695.5307, Accuracy: 82.89%
# NN saved.
# Epoch: [39/60]
# Training Loss: 694.8152, Accuracy: 83.19%
# NN saved.
# Epoch: [40/60]
# Training Loss: 678.4215, Accuracy: 84.12%
# NN saved.
# Epoch: [41/60]
# Training Loss: 661.6191, Accuracy: 84.36%
# NN saved.
# Epoch: [42/60]
# Training Loss: 584.2595, Accuracy: 85.34%
# NN saved.
# Epoch: [43/60]
# Training Loss: 680.5684, Accuracy: 83.19%
# NN saved.
# Epoch: [44/60]
# Training Loss: 673.3415, Accuracy: 83.33%
# NN saved.
# Epoch: [45/60]
# Training Loss: 683.3781, Accuracy: 83.19%
# NN saved.
# Epoch: [46/60]
# Training Loss: 636.0167, Accuracy: 84.26%
# NN saved.
# Epoch: [47/60]
# Training Loss: 539.6217, Accuracy: 86.32%
# NN saved.
# Epoch: [48/60]
# Training Loss: 604.7243, Accuracy: 84.71%
# NN saved.
# Epoch: [49/60]
# Training Loss: 610.8614, Accuracy: 84.66%
# NN saved.
# Epoch: [50/60]
# Training Loss: 590.7476, Accuracy: 84.95%
# NN saved.
# Epoch: [51/60]
# Training Loss: 600.5182, Accuracy: 84.95%
# NN saved.
# Epoch: [52/60]
# Training Loss: 588.5675, Accuracy: 85.34%
# NN saved.
# Epoch: [53/60]
# Training Loss: 583.8990, Accuracy: 85.15%
# NN saved.
# Epoch: [54/60]
# Training Loss: 571.9611, Accuracy: 85.64%
# NN saved.
# Epoch: [55/60]
# Training Loss: 592.9237, Accuracy: 85.59%
# NN saved.
# Epoch: [56/60]
# Training Loss: 536.3938, Accuracy: 86.67%
# NN saved.
# Epoch: [57/60]
# Training Loss: 530.8413, Accuracy: 86.76%
# NN saved.
# Epoch: [58/60]
# Training Loss: 583.6846, Accuracy: 84.75%
# NN saved.
# Epoch: [59/60]
# Training Loss: 582.6599, Accuracy: 84.22%
# NN saved.
# Epoch: [60/60]
# Training Loss: 549.8349, Accuracy: 85.00%
# NN saved.
# Training Complete in: 00h 20m 08s
# Starting training with lr: 8e-05
# Epoch: [1/60]
# Training Loss: 4709.0798, Accuracy: 1.57%
# NN saved.
# Epoch: [2/60]
# Training Loss: 4433.0565, Accuracy: 2.89%
# NN saved.
# Epoch: [3/60]
# Training Loss: 4126.6324, Accuracy: 5.78%
# NN saved.
# Epoch: [4/60]
# Training Loss: 3905.7194, Accuracy: 8.87%
# NN saved.
# Epoch: [5/60]
# Training Loss: 3563.9114, Accuracy: 13.24%
# NN saved.
# Epoch: [6/60]
# Training Loss: 3189.3749, Accuracy: 21.62%
# NN saved.
# Epoch: [7/60]
# Training Loss: 2806.7892, Accuracy: 28.82%
# NN saved.
# Epoch: [8/60]
# Training Loss: 2448.9994, Accuracy: 36.86%
# NN saved.
# Epoch: [9/60]
# Training Loss: 2144.2631, Accuracy: 44.51%
# NN saved.
# Epoch: [10/60]
# Training Loss: 1852.8699, Accuracy: 52.60%
# NN saved.
# Epoch: [11/60]
# Training Loss: 1583.6322, Accuracy: 60.05%
# NN saved.
# Epoch: [12/60]
# Training Loss: 1406.4664, Accuracy: 65.44%
# NN saved.
# Epoch: [13/60]
# Training Loss: 1210.6877, Accuracy: 71.18%
# NN saved.
# Epoch: [14/60]
# Training Loss: 1070.7463, Accuracy: 74.12%
# NN saved.
# Epoch: [15/60]
# Training Loss: 1037.3377, Accuracy: 75.64%
# NN saved.
# Epoch: [16/60]
# Training Loss: 982.5879, Accuracy: 76.91%
# NN saved.
# Epoch: [17/60]
# Training Loss: 930.2014, Accuracy: 78.73%
# NN saved.
# Epoch: [18/60]
# Training Loss: 922.6525, Accuracy: 78.77%
# NN saved.
# Epoch: [19/60]
# Training Loss: 887.3386, Accuracy: 79.90%
# NN saved.
# Epoch: [20/60]
# Training Loss: 839.1377, Accuracy: 80.78%
# NN saved.
# Epoch: [21/60]
# Training Loss: 846.7908, Accuracy: 79.90%
# NN saved.
# Epoch: [22/60]
# Training Loss: 837.9978, Accuracy: 80.93%
# NN saved.
# Epoch: [23/60]
# Training Loss: 798.6953, Accuracy: 80.83%
# NN saved.
# Epoch: [24/60]
# Training Loss: 796.3127, Accuracy: 81.62%
# NN saved.
# Epoch: [25/60]
# Training Loss: 766.6686, Accuracy: 81.72%
# NN saved.
# Epoch: [26/60]
# Training Loss: 772.6331, Accuracy: 81.18%
# NN saved.
# Epoch: [27/60]
# Training Loss: 797.6231, Accuracy: 81.08%
# NN saved.
# Epoch: [28/60]
# Training Loss: 776.5500, Accuracy: 81.96%
# NN saved.
# Epoch: [29/60]
# Training Loss: 736.8685, Accuracy: 82.79%
# NN saved.
# Epoch: [30/60]
# Training Loss: 719.6469, Accuracy: 83.28%
# NN saved.
# Epoch: [31/60]
# Training Loss: 754.7789, Accuracy: 82.40%
# NN saved.
# Epoch: [32/60]
# Training Loss: 717.3108, Accuracy: 82.79%
# NN saved.
# Epoch: [33/60]
# Training Loss: 711.3183, Accuracy: 83.04%
# NN saved.
# Epoch: [34/60]
# Training Loss: 684.2290, Accuracy: 84.22%
# NN saved.
# Epoch: [35/60]
# Training Loss: 622.7177, Accuracy: 84.61%
# NN saved.
# Epoch: [36/60]
# Training Loss: 706.7506, Accuracy: 82.89%
# NN saved.
# Epoch: [37/60]
# Training Loss: 687.8455, Accuracy: 83.53%
# NN saved.
# Epoch: [38/60]
# Training Loss: 676.1265, Accuracy: 82.99%
# NN saved.
# Epoch: [39/60]
# Training Loss: 656.6076, Accuracy: 84.17%
# NN saved.
# Epoch: [40/60]
# Training Loss: 635.4963, Accuracy: 84.17%
# NN saved.
# Epoch: [41/60]
# Training Loss: 681.2653, Accuracy: 83.92%
# NN saved.
# Epoch: [42/60]
# Training Loss: 654.5062, Accuracy: 83.82%
# NN saved.
# Epoch: [43/60]
# Training Loss: 666.8548, Accuracy: 83.77%
# NN saved.
# Epoch: [44/60]
# Training Loss: 649.0063, Accuracy: 82.94%
# NN saved.
# Epoch: [45/60]
# Training Loss: 609.7937, Accuracy: 85.05%
# NN saved.
# Epoch: [46/60]
# Training Loss: 654.4441, Accuracy: 83.48%
# NN saved.
# Epoch: [47/60]
# Training Loss: 618.0963, Accuracy: 85.59%
# NN saved.
# Epoch: [48/60]
# Training Loss: 650.4729, Accuracy: 83.77%
# NN saved.
# Epoch: [49/60]
# Training Loss: 628.5183, Accuracy: 84.46%
# NN saved.
# Epoch: [50/60]
# Training Loss: 624.1646, Accuracy: 84.46%
# NN saved.
# Epoch: [51/60]
# Training Loss: 556.9047, Accuracy: 86.27%
# NN saved.
# Epoch: [52/60]
# Training Loss: 607.5342, Accuracy: 84.75%
# NN saved.
# Epoch: [53/60]
# Training Loss: 598.1574, Accuracy: 85.34%
# NN saved.
# Epoch: [54/60]
# Training Loss: 595.9991, Accuracy: 84.90%
# NN saved.
# Epoch: [55/60]
# Training Loss: 585.0920, Accuracy: 85.10%
# NN saved.
# Epoch: [56/60]
# Training Loss: 521.6298, Accuracy: 86.86%
# NN saved.
# Epoch: [57/60]
# Training Loss: 612.5774, Accuracy: 84.66%
# NN saved.
# Epoch: [58/60]
# Training Loss: 535.8707, Accuracy: 86.47%
# NN saved.
# Epoch: [59/60]
# Training Loss: 612.3497, Accuracy: 84.41%
# NN saved.
# Epoch: [60/60]
# Training Loss: 587.5343, Accuracy: 85.20%
# NN saved.
# Training Complete in: 00h 19m 47s
# Starting training with lr: 7e-05
# Epoch: [1/60]
# Training Loss: 4701.5767, Accuracy: 1.37%
# NN saved.
# Epoch: [2/60]
# Training Loss: 4260.9265, Accuracy: 3.58%
# NN saved.
# Epoch: [3/60]
# Training Loss: 3881.2010, Accuracy: 7.21%
# NN saved.
# Epoch: [4/60]
# Training Loss: 3603.8082, Accuracy: 11.27%
# NN saved.
# Epoch: [5/60]
# Training Loss: 3407.4845, Accuracy: 14.90%
# NN saved.
# Epoch: [6/60]
# Training Loss: 3112.3184, Accuracy: 20.44%
# NN saved.
# Epoch: [7/60]
# Training Loss: 2893.8003, Accuracy: 25.29%
# NN saved.
# Epoch: [8/60]
# Training Loss: 2598.2919, Accuracy: 32.06%
# NN saved.
# Epoch: [9/60]
# Training Loss: 2318.5097, Accuracy: 40.25%
# NN saved.
# Epoch: [10/60]
# Training Loss: 2011.9989, Accuracy: 47.45%
# NN saved.
# Epoch: [11/60]
# Training Loss: 1794.1719, Accuracy: 54.46%
# NN saved.
# Epoch: [12/60]
# Training Loss: 1558.9597, Accuracy: 61.23%
# NN saved.
# Epoch: [13/60]
# Training Loss: 1334.7377, Accuracy: 66.52%
# NN saved.
# Epoch: [14/60]
# Training Loss: 1260.8153, Accuracy: 69.80%
# NN saved.
# Epoch: [15/60]
# Training Loss: 1108.0633, Accuracy: 73.04%
# NN saved.
# Epoch: [16/60]
# Training Loss: 1041.7895, Accuracy: 75.88%
# NN saved.
# Epoch: [17/60]
# Training Loss: 993.2113, Accuracy: 76.23%
# NN saved.
# Epoch: [18/60]
# Training Loss: 936.8236, Accuracy: 78.09%
# NN saved.
# Epoch: [19/60]
# Training Loss: 905.4959, Accuracy: 79.66%
# NN saved.
# Epoch: [20/60]
# Training Loss: 816.0287, Accuracy: 80.88%
# NN saved.
# Epoch: [21/60]
# Training Loss: 853.3874, Accuracy: 80.44%
# NN saved.
# Epoch: [22/60]
# Training Loss: 826.9274, Accuracy: 80.44%
# NN saved.
# Epoch: [23/60]
# Training Loss: 852.1389, Accuracy: 80.69%
# NN saved.
# Epoch: [24/60]
# Training Loss: 812.7832, Accuracy: 81.08%
# NN saved.
# Epoch: [25/60]
# Training Loss: 851.1384, Accuracy: 80.15%
# NN saved.
# Epoch: [26/60]
# Training Loss: 815.0931, Accuracy: 80.59%
# NN saved.
# Epoch: [27/60]
# Training Loss: 815.7792, Accuracy: 81.18%
# NN saved.
# Epoch: [28/60]
# Training Loss: 773.6804, Accuracy: 81.18%
# NN saved.
# Epoch: [29/60]
# Training Loss: 764.0909, Accuracy: 81.67%
# NN saved.
# Epoch: [30/60]
# Training Loss: 735.4239, Accuracy: 82.55%
# NN saved.
# Epoch: [31/60]
# Training Loss: 726.0496, Accuracy: 82.94%
# NN saved.
# Epoch: [32/60]
# Training Loss: 731.0727, Accuracy: 82.45%
# NN saved.
# Epoch: [33/60]
# Training Loss: 679.3632, Accuracy: 82.79%
# NN saved.
# Epoch: [34/60]
# Training Loss: 731.0025, Accuracy: 83.14%
# NN saved.
# Epoch: [35/60]
# Training Loss: 687.7471, Accuracy: 84.02%
# NN saved.
# Epoch: [36/60]
# Training Loss: 728.9170, Accuracy: 82.25%
# NN saved.
# Epoch: [37/60]
# Training Loss: 689.4452, Accuracy: 83.14%
# NN saved.
# Epoch: [38/60]
# Training Loss: 677.4579, Accuracy: 82.55%
# NN saved.
# Epoch: [39/60]
# Training Loss: 678.7440, Accuracy: 83.04%
# NN saved.
# Epoch: [40/60]
# Training Loss: 648.8465, Accuracy: 84.51%
# NN saved.
# Epoch: [41/60]
# Training Loss: 659.3954, Accuracy: 83.43%
# NN saved.
# Epoch: [42/60]
# Training Loss: 594.9609, Accuracy: 85.20%
# NN saved.
# Epoch: [43/60]
# Training Loss: 686.4473, Accuracy: 82.99%
# NN saved.
# Epoch: [44/60]
# Training Loss: 672.1385, Accuracy: 83.58%
# NN saved.
# Epoch: [45/60]
# Training Loss: 644.9788, Accuracy: 83.24%
# NN saved.
# Epoch: [46/60]
# Training Loss: 631.8141, Accuracy: 84.80%
# NN saved.
# Epoch: [47/60]
# Training Loss: 580.5327, Accuracy: 85.74%
# NN saved.
# Epoch: [48/60]
# Training Loss: 581.3004, Accuracy: 85.44%
# NN saved.
# Epoch: [49/60]
# Training Loss: 555.7897, Accuracy: 85.69%
# NN saved.
# Epoch: [50/60]
# Training Loss: 620.9743, Accuracy: 84.61%
# NN saved.
# Epoch: [51/60]
# Training Loss: 523.0770, Accuracy: 86.81%
# NN saved.
# Epoch: [52/60]
# Training Loss: 590.1684, Accuracy: 83.68%
# NN saved.
# Epoch: [53/60]
# Training Loss: 581.5637, Accuracy: 85.29%
# NN saved.
# Epoch: [54/60]
# Training Loss: 572.3182, Accuracy: 85.74%
# NN saved.
# Epoch: [55/60]
# Training Loss: 612.3685, Accuracy: 84.22%
# NN saved.
# Epoch: [56/60]
# Training Loss: 528.1425, Accuracy: 86.13%
# NN saved.
# Epoch: [57/60]
# Training Loss: 550.6741, Accuracy: 84.95%
# NN saved.
# Epoch: [58/60]
# Training Loss: 577.0508, Accuracy: 85.44%
# NN saved.
# Epoch: [59/60]
# Training Loss: 546.2930, Accuracy: 86.57%
# NN saved.
# Epoch: [60/60]
# Training Loss: 563.4339, Accuracy: 86.03%
# NN saved.
# Training Complete in: 00h 18m 43s
# Starting training with lr: 5e-05
# Epoch: [1/60]
# Training Loss: 4720.8469, Accuracy: 0.93%
# NN saved.
# Epoch: [2/60]
# Training Loss: 4406.6000, Accuracy: 2.79%
# NN saved.
# Epoch: [3/60]
# Training Loss: 4062.6244, Accuracy: 6.18%
# NN saved.
# Epoch: [4/60]
# Training Loss: 3806.8770, Accuracy: 9.22%
# NN saved.
# Epoch: [5/60]
# Training Loss: 3408.3943, Accuracy: 16.23%
# NN saved.
# Epoch: [6/60]
# Training Loss: 2995.4967, Accuracy: 24.71%
# NN saved.
# Epoch: [7/60]
# Training Loss: 2621.1220, Accuracy: 33.19%
# NN saved.
# Epoch: [8/60]
# Training Loss: 2192.2430, Accuracy: 43.43%
# NN saved.
# Epoch: [9/60]
# Training Loss: 1918.6102, Accuracy: 52.06%
# NN saved.
# Epoch: [10/60]
# Training Loss: 1648.0772, Accuracy: 58.92%
# NN saved.
# Epoch: [11/60]
# Training Loss: 1393.4665, Accuracy: 64.85%
# NN saved.
# Epoch: [12/60]
# Training Loss: 1215.2518, Accuracy: 71.67%
# NN saved.
# Epoch: [13/60]
# Training Loss: 1107.8204, Accuracy: 74.31%
# NN saved.
# Epoch: [14/60]
# Training Loss: 1089.8247, Accuracy: 75.15%
# NN saved.
# Epoch: [15/60]
# Training Loss: 1019.8655, Accuracy: 76.67%
# NN saved.
# Epoch: [16/60]
# Training Loss: 952.0181, Accuracy: 78.68%
# NN saved.
# Epoch: [17/60]
# Training Loss: 885.7180, Accuracy: 79.75%
# NN saved.
# Epoch: [18/60]
# Training Loss: 812.1807, Accuracy: 81.42%
# NN saved.
# Epoch: [19/60]
# Training Loss: 854.8789, Accuracy: 79.80%
# NN saved.
# Epoch: [20/60]
# Training Loss: 872.5301, Accuracy: 79.46%
# NN saved.
# Epoch: [21/60]
# Training Loss: 817.6219, Accuracy: 81.32%
# NN saved.
# Epoch: [22/60]
# Training Loss: 715.0102, Accuracy: 83.77%
# NN saved.
# Epoch: [23/60]
# Training Loss: 795.6641, Accuracy: 81.81%
# NN saved.
# Epoch: [24/60]
# Training Loss: 774.4459, Accuracy: 82.21%
# NN saved.
# Epoch: [25/60]
# Training Loss: 804.5201, Accuracy: 81.18%
# NN saved.
# Epoch: [26/60]
# Training Loss: 771.5086, Accuracy: 82.21%
# NN saved.
# Epoch: [27/60]
# Training Loss: 723.3418, Accuracy: 83.53%
# NN saved.
# Epoch: [28/60]
# Training Loss: 738.8693, Accuracy: 82.65%
# NN saved.
# Epoch: [29/60]
# Training Loss: 737.2905, Accuracy: 82.99%
# NN saved.
# Epoch: [30/60]
# Training Loss: 750.2161, Accuracy: 82.01%
# NN saved.
# Epoch: [31/60]
# Training Loss: 705.4092, Accuracy: 83.33%
# NN saved.
# Epoch: [32/60]
# Training Loss: 700.4318, Accuracy: 83.38%
# NN saved.
# Epoch: [33/60]
# Training Loss: 654.6480, Accuracy: 84.02%
# NN saved.
# Epoch: [34/60]
# Training Loss: 691.7183, Accuracy: 83.09%
# NN saved.
# Epoch: [35/60]
# Training Loss: 732.4727, Accuracy: 82.11%
# NN saved.
# Epoch: [36/60]
# Training Loss: 683.5429, Accuracy: 83.38%
# NN saved.
# Epoch: [37/60]
# Training Loss: 713.4497, Accuracy: 82.70%
# NN saved.
# Epoch: [38/60]
# Training Loss: 670.1420, Accuracy: 83.77%
# NN saved.
# Epoch: [39/60]
# Training Loss: 678.5856, Accuracy: 83.14%
# NN saved.
# Epoch: [40/60]
# Training Loss: 656.2073, Accuracy: 84.12%
# NN saved.
# Epoch: [41/60]
# Training Loss: 619.9208, Accuracy: 85.00%
# NN saved.
# Epoch: [42/60]
# Training Loss: 614.8153, Accuracy: 84.46%
# NN saved.
# Epoch: [43/60]
# Training Loss: 560.3081, Accuracy: 86.72%
# NN saved.
# Epoch: [44/60]
# Training Loss: 608.4546, Accuracy: 84.95%
# NN saved.
# Epoch: [45/60]
# Training Loss: 607.2302, Accuracy: 84.90%
# NN saved.
# Epoch: [46/60]
# Training Loss: 594.4911, Accuracy: 85.00%
# NN saved.
# Epoch: [47/60]
# Training Loss: 619.7933, Accuracy: 84.80%
# NN saved.
# Epoch: [48/60]
# Training Loss: 634.8167, Accuracy: 84.17%
# NN saved.
# Epoch: [49/60]
# Training Loss: 611.4010, Accuracy: 84.46%
# NN saved.
# Epoch: [50/60]
# Training Loss: 568.4669, Accuracy: 85.83%
# NN saved.
# Epoch: [51/60]
# Training Loss: 593.4222, Accuracy: 85.15%
# NN saved.
# Epoch: [52/60]
# Training Loss: 599.3811, Accuracy: 84.95%
# NN saved.
# Epoch: [53/60]
# Training Loss: 608.2191, Accuracy: 84.61%
# NN saved.
# Epoch: [54/60]
# Training Loss: 541.9732, Accuracy: 85.88%
# NN saved.
# Epoch: [55/60]
# Training Loss: 561.5468, Accuracy: 85.69%
# NN saved.
# Epoch: [56/60]
# Training Loss: 562.4631, Accuracy: 86.18%
# NN saved.
# Epoch: [57/60]
# Training Loss: 508.2269, Accuracy: 86.52%
# NN saved.
# Epoch: [58/60]
# Training Loss: 534.4785, Accuracy: 86.13%
# NN saved.
# Epoch: [59/60]
# Training Loss: 522.5703, Accuracy: 87.55%
# NN saved.
# Epoch: [60/60]
# Training Loss: 567.5650, Accuracy: 86.42%
# NN saved.
# Training Complete in: 00h 18m 39s
# Starting training with lr: 2.5e-05
# Epoch: [1/60]
# Training Loss: 4691.4782, Accuracy: 0.98%
# NN saved.
# Epoch: [2/60]
# Training Loss: 4322.8697, Accuracy: 2.75%
# NN saved.
# Epoch: [3/60]
# Training Loss: 4026.3989, Accuracy: 6.32%
# NN saved.
# Epoch: [4/60]
# Training Loss: 3772.9130, Accuracy: 9.26%
# NN saved.
# Epoch: [5/60]
# Training Loss: 3493.6990, Accuracy: 12.65%
# NN saved.
# Epoch: [6/60]
# Training Loss: 3232.4583, Accuracy: 18.87%
# NN saved.
# Epoch: [7/60]
# Training Loss: 2959.4050, Accuracy: 23.97%
# NN saved.
# Epoch: [8/60]
# Training Loss: 2619.4112, Accuracy: 32.25%
# NN saved.
# Epoch: [9/60]
# Training Loss: 2383.6916, Accuracy: 38.73%
# NN saved.
# Epoch: [10/60]
# Training Loss: 2043.0636, Accuracy: 47.01%
# NN saved.
# Epoch: [11/60]
# Training Loss: 1827.7199, Accuracy: 52.79%
# NN saved.
# Epoch: [12/60]
# Training Loss: 1535.0148, Accuracy: 60.93%
# NN saved.
# Epoch: [13/60]
# Training Loss: 1336.4702, Accuracy: 68.53%
# NN saved.
# Epoch: [14/60]
# Training Loss: 1189.4036, Accuracy: 71.27%
# NN saved.
# Epoch: [15/60]
# Training Loss: 1095.7856, Accuracy: 74.02%
# NN saved.
# Epoch: [16/60]
# Training Loss: 1027.0826, Accuracy: 75.88%
# NN saved.
# Epoch: [17/60]
# Training Loss: 1006.7565, Accuracy: 76.62%
# NN saved.
# Epoch: [18/60]
# Training Loss: 941.5821, Accuracy: 79.02%
# NN saved.
# Epoch: [19/60]
# Training Loss: 870.9499, Accuracy: 79.85%
# NN saved.
# Epoch: [20/60]
# Training Loss: 885.4612, Accuracy: 79.46%
# NN saved.
# Epoch: [21/60]
# Training Loss: 856.6283, Accuracy: 79.71%
# NN saved.
# Epoch: [22/60]
# Training Loss: 785.1376, Accuracy: 82.11%
# NN saved.
# Epoch: [23/60]
# Training Loss: 840.5122, Accuracy: 80.64%
# NN saved.
# Epoch: [24/60]
# Training Loss: 784.7679, Accuracy: 81.08%
# NN saved.
# Epoch: [25/60]
# Training Loss: 751.5267, Accuracy: 82.30%
# NN saved.
# Epoch: [26/60]
# Training Loss: 821.4718, Accuracy: 80.54%
# NN saved.
# Epoch: [27/60]
# Training Loss: 773.6020, Accuracy: 82.11%
# NN saved.
# Epoch: [28/60]
# Training Loss: 763.1342, Accuracy: 82.06%
# NN saved.
# Epoch: [29/60]
# Training Loss: 797.7301, Accuracy: 80.93%
# NN saved.
# Epoch: [30/60]
# Training Loss: 764.5500, Accuracy: 82.60%
# NN saved.
# Epoch: [31/60]
# Training Loss: 810.1261, Accuracy: 80.64%
# NN saved.
# Epoch: [32/60]
# Training Loss: 697.5989, Accuracy: 83.77%
# NN saved.
# Epoch: [33/60]
# Training Loss: 709.4210, Accuracy: 82.75%
# NN saved.
# Epoch: [34/60]
# Training Loss: 736.5013, Accuracy: 82.25%
# NN saved.
# Epoch: [35/60]
# Training Loss: 680.5494, Accuracy: 83.77%
# NN saved.
# Epoch: [36/60]
# Training Loss: 700.0095, Accuracy: 83.38%
# NN saved.
# Epoch: [37/60]
# Training Loss: 662.8021, Accuracy: 84.41%
# NN saved.
# Epoch: [38/60]
# Training Loss: 710.0335, Accuracy: 82.35%
# NN saved.
# Epoch: [39/60]
# Training Loss: 673.2765, Accuracy: 83.09%
# NN saved.
# Epoch: [40/60]
# Training Loss: 617.3303, Accuracy: 85.00%
# NN saved.
# Epoch: [41/60]
# Training Loss: 675.2182, Accuracy: 83.82%
# NN saved.
# Epoch: [42/60]
# Training Loss: 615.6688, Accuracy: 84.41%
# NN saved.
# Epoch: [43/60]
# Training Loss: 697.8612, Accuracy: 82.55%
# NN saved.
# Epoch: [44/60]
# Training Loss: 638.0249, Accuracy: 84.12%
# NN saved.
# Epoch: [45/60]
# Training Loss: 622.7052, Accuracy: 84.61%
# NN saved.
# Epoch: [46/60]
# Training Loss: 597.7940, Accuracy: 85.25%
# NN saved.
# Epoch: [47/60]
# Training Loss: 586.9562, Accuracy: 85.69%
# NN saved.
# Epoch: [48/60]
# Training Loss: 617.4193, Accuracy: 84.61%
# NN saved.
# Epoch: [49/60]
# Training Loss: 621.0131, Accuracy: 84.26%
# NN saved.
# Epoch: [50/60]
# Training Loss: 579.1540, Accuracy: 85.05%
# NN saved.
# Epoch: [51/60]
# Training Loss: 602.3751, Accuracy: 85.05%
# NN saved.
# Epoch: [52/60]
# Training Loss: 668.9241, Accuracy: 82.99%
# NN saved.
# Epoch: [53/60]
# Training Loss: 529.8276, Accuracy: 86.76%
# NN saved.
# Epoch: [54/60]
# Training Loss: 595.9807, Accuracy: 85.44%
# NN saved.
# Epoch: [55/60]
# Training Loss: 581.1214, Accuracy: 85.69%
# NN saved.
# Epoch: [56/60]
# Training Loss: 563.5502, Accuracy: 85.83%
# NN saved.
# Epoch: [57/60]
# Training Loss: 583.3549, Accuracy: 85.54%
# NN saved.
# Epoch: [58/60]
# Training Loss: 543.7406, Accuracy: 85.78%
# NN saved.
# Epoch: [59/60]
# Training Loss: 549.8880, Accuracy: 85.83%
# NN saved.
# Epoch: [60/60]
# Training Loss: 500.7700, Accuracy: 86.76%
# NN saved.
# Training Complete in: 00h 18m 47s
# Starting training with lr: 1e-05
# Epoch: [1/60]
# Training Loss: 4677.7482, Accuracy: 1.52%
# NN saved.
# Epoch: [2/60]
# Training Loss: 4262.1805, Accuracy: 4.12%
# NN saved.
# Epoch: [3/60]
# Training Loss: 3866.4820, Accuracy: 7.21%
# NN saved.
# Epoch: [4/60]
# Training Loss: 3585.8301, Accuracy: 11.67%
# NN saved.
# Epoch: [5/60]
# Training Loss: 3366.6304, Accuracy: 15.69%
# NN saved.
# Epoch: [6/60]
# Training Loss: 3033.5081, Accuracy: 22.50%
# NN saved.
# Epoch: [7/60]
# Training Loss: 2781.7269, Accuracy: 27.60%
# NN saved.
# Epoch: [8/60]
# Training Loss: 2504.7026, Accuracy: 33.24%
# NN saved.
# Epoch: [9/60]
# Training Loss: 2228.2662, Accuracy: 40.20%
# NN saved.
# Epoch: [10/60]
# Training Loss: 1951.4446, Accuracy: 49.07%
# NN saved.
# Epoch: [11/60]
# Training Loss: 1659.9642, Accuracy: 57.11%
# NN saved.
# Epoch: [12/60]
# Training Loss: 1438.6231, Accuracy: 64.12%
# NN saved.
# Epoch: [13/60]
# Training Loss: 1373.7027, Accuracy: 65.98%
# NN saved.
# Epoch: [14/60]
# Training Loss: 1191.9715, Accuracy: 71.27%
# NN saved.
# Epoch: [15/60]
# Training Loss: 1120.6198, Accuracy: 74.26%
# NN saved.
# Epoch: [16/60]
# Training Loss: 993.8064, Accuracy: 76.91%
# NN saved.
# Epoch: [17/60]
# Training Loss: 960.6033, Accuracy: 77.70%
# NN saved.
# Epoch: [18/60]
# Training Loss: 994.5125, Accuracy: 76.52%
# NN saved.
# Epoch: [19/60]
# Training Loss: 895.6647, Accuracy: 79.17%
# NN saved.
# Epoch: [20/60]
# Training Loss: 875.5484, Accuracy: 80.34%
# NN saved.
# Epoch: [21/60]
# Training Loss: 919.4592, Accuracy: 78.82%
# NN saved.
# Epoch: [22/60]
# Training Loss: 808.6588, Accuracy: 81.18%
# NN saved.
# Epoch: [23/60]
# Training Loss: 780.6254, Accuracy: 81.96%
# NN saved.
# Epoch: [24/60]
# Training Loss: 758.8816, Accuracy: 81.27%
# NN saved.
# Epoch: [25/60]
# Training Loss: 803.3423, Accuracy: 81.27%
# NN saved.
# Epoch: [26/60]
# Training Loss: 741.4715, Accuracy: 82.65%
# NN saved.
# Epoch: [27/60]
# Training Loss: 769.5655, Accuracy: 81.67%
# NN saved.
# Epoch: [28/60]
# Training Loss: 736.3102, Accuracy: 82.16%
# NN saved.
# Epoch: [29/60]
# Training Loss: 754.8711, Accuracy: 82.65%
# NN saved.
# Epoch: [30/60]
# Training Loss: 719.2653, Accuracy: 82.79%
# NN saved.
# Epoch: [31/60]
# Training Loss: 816.3962, Accuracy: 79.80%
# NN saved.
# Epoch: [32/60]
# Training Loss: 784.7513, Accuracy: 81.18%
# NN saved.
# Epoch: [33/60]
# Training Loss: 790.6867, Accuracy: 80.98%
# NN saved.
# Epoch: [34/60]
# Training Loss: 739.2722, Accuracy: 81.37%
# NN saved.
# Epoch: [35/60]
# Training Loss: 674.7786, Accuracy: 83.33%
# NN saved.
# Epoch: [36/60]
# Training Loss: 710.5166, Accuracy: 82.94%
# NN saved.
# Epoch: [37/60]
# Training Loss: 688.4473, Accuracy: 82.70%
# NN saved.
# Epoch: [38/60]
# Training Loss: 720.2835, Accuracy: 82.35%
# NN saved.
# Epoch: [39/60]
# Training Loss: 700.4855, Accuracy: 82.84%
# NN saved.
# Epoch: [40/60]
# Training Loss: 707.9340, Accuracy: 82.35%
# NN saved.
# Epoch: [41/60]
# Training Loss: 673.2480, Accuracy: 83.87%
# NN saved.
# Epoch: [42/60]
# Training Loss: 638.9161, Accuracy: 84.31%
# NN saved.
# Epoch: [43/60]
# Training Loss: 643.6930, Accuracy: 84.31%
# NN saved.
# Epoch: [44/60]
# Training Loss: 671.6306, Accuracy: 83.82%
# NN saved.
# Epoch: [45/60]
# Training Loss: 652.1044, Accuracy: 83.87%
# NN saved.
# Epoch: [46/60]
# Training Loss: 623.1726, Accuracy: 84.07%
# NN saved.
# Epoch: [47/60]
# Training Loss: 616.0330, Accuracy: 84.75%
# NN saved.
# Epoch: [48/60]
# Training Loss: 608.0786, Accuracy: 84.95%
# NN saved.
# Epoch: [49/60]
# Training Loss: 575.9898, Accuracy: 85.44%
# NN saved.
# Epoch: [50/60]
# Training Loss: 596.9078, Accuracy: 85.34%
# NN saved.
# Epoch: [51/60]
# Training Loss: 610.6920, Accuracy: 85.20%
# NN saved.
# Epoch: [52/60]
# Training Loss: 544.2704, Accuracy: 86.18%
# NN saved.
# Epoch: [53/60]
# Training Loss: 578.4544, Accuracy: 85.74%
# NN saved.
# Epoch: [54/60]
# Training Loss: 548.4092, Accuracy: 86.13%
# NN saved.
# Epoch: [55/60]
# Training Loss: 572.4866, Accuracy: 85.00%
# NN saved.
# Epoch: [56/60]
# Training Loss: 538.6467, Accuracy: 86.47%
# NN saved.
# Epoch: [57/60]
# Training Loss: 613.5748, Accuracy: 83.77%
# NN saved.
# Epoch: [58/60]
# Training Loss: 540.4907, Accuracy: 86.57%
# NN saved.
# Epoch: [59/60]
# Training Loss: 571.7218, Accuracy: 85.49%
# NN saved.
# Epoch: [60/60]
# Training Loss: 504.3986, Accuracy: 86.76%
# NN saved.
# Training Complete in: 00h 18m 23s
# Starting training with lr: 7.5e-06
# Epoch: [1/60]
# Training Loss: 4693.1116, Accuracy: 1.42%
# NN saved.
# Epoch: [2/60]
# Training Loss: 4368.7257, Accuracy: 2.89%
# NN saved.
# Epoch: [3/60]
# Training Loss: 4058.3876, Accuracy: 5.69%
# NN saved.
# Epoch: [4/60]
# Training Loss: 3728.6205, Accuracy: 10.10%
# NN saved.
# Epoch: [5/60]
# Training Loss: 3448.0326, Accuracy: 14.02%
# NN saved.
# Epoch: [6/60]
# Training Loss: 3134.4541, Accuracy: 21.76%
# NN saved.
# Epoch: [7/60]
# Training Loss: 2883.5056, Accuracy: 25.20%
# NN saved.
# Epoch: [8/60]
# Training Loss: 2481.1638, Accuracy: 36.42%
# NN saved.
# Epoch: [9/60]
# Training Loss: 2157.5625, Accuracy: 42.89%
# NN saved.
# Epoch: [10/60]
# Training Loss: 1872.6241, Accuracy: 51.62%
# NN saved.
# Epoch: [11/60]
# Training Loss: 1586.6460, Accuracy: 60.64%
# NN saved.
# Epoch: [12/60]
# Training Loss: 1450.2448, Accuracy: 63.82%
# NN saved.
# Epoch: [13/60]
# Training Loss: 1237.5432, Accuracy: 70.74%
# NN saved.
# Epoch: [14/60]
# Training Loss: 1114.1233, Accuracy: 72.89%
# NN saved.
# Epoch: [15/60]
# Training Loss: 1032.9692, Accuracy: 76.18%
# NN saved.
# Epoch: [16/60]
# Training Loss: 1007.1813, Accuracy: 76.27%
# NN saved.
# Epoch: [17/60]
# Training Loss: 886.5791, Accuracy: 79.26%
# NN saved.
# Epoch: [18/60]
# Training Loss: 924.0520, Accuracy: 79.26%
# NN saved.
# Epoch: [19/60]
# Training Loss: 855.5648, Accuracy: 79.85%
# NN saved.
# Epoch: [20/60]
# Training Loss: 819.5324, Accuracy: 81.27%
# NN saved.
# Epoch: [21/60]
# Training Loss: 854.3882, Accuracy: 80.64%
# NN saved.
# Epoch: [22/60]
# Training Loss: 777.4389, Accuracy: 82.55%
# NN saved.
# Epoch: [23/60]
# Training Loss: 766.9986, Accuracy: 81.47%
# NN saved.
# Epoch: [24/60]
# Training Loss: 770.7465, Accuracy: 82.25%
# NN saved.
# Epoch: [25/60]
# Training Loss: 783.9025, Accuracy: 81.81%
# NN saved.
# Epoch: [26/60]
# Training Loss: 750.1781, Accuracy: 81.72%
# NN saved.
# Epoch: [27/60]
# Training Loss: 753.0550, Accuracy: 82.45%
# NN saved.
# Epoch: [28/60]
# Training Loss: 769.6183, Accuracy: 81.42%
# NN saved.
# Epoch: [29/60]
# Training Loss: 741.3605, Accuracy: 82.75%
# NN saved.
# Epoch: [30/60]
# Training Loss: 742.7865, Accuracy: 82.94%
# NN saved.
# Epoch: [31/60]
# Training Loss: 724.8893, Accuracy: 83.19%
# NN saved.
# Epoch: [32/60]
# Training Loss: 703.2653, Accuracy: 82.84%
# NN saved.
# Epoch: [33/60]
# Training Loss: 695.6757, Accuracy: 82.70%
# NN saved.
# Epoch: [34/60]
# Training Loss: 680.0693, Accuracy: 82.94%
# NN saved.
# Epoch: [35/60]
# Training Loss: 667.3310, Accuracy: 84.46%
# NN saved.
# Epoch: [36/60]
# Training Loss: 685.4460, Accuracy: 83.58%
# NN saved.
# Epoch: [37/60]
# Training Loss: 673.9090, Accuracy: 83.92%
# NN saved.
# Epoch: [38/60]
# Training Loss: 663.3467, Accuracy: 84.02%
# NN saved.
# Epoch: [39/60]
# Training Loss: 641.0051, Accuracy: 84.80%
# NN saved.
# Epoch: [40/60]
# Training Loss: 656.3168, Accuracy: 83.73%
# NN saved.
# Epoch: [41/60]
# Training Loss: 625.0524, Accuracy: 84.17%
# NN saved.
# Epoch: [42/60]
# Training Loss: 629.4530, Accuracy: 84.56%
# NN saved.
# Epoch: [43/60]
# Training Loss: 702.1464, Accuracy: 82.25%
# NN saved.
# Epoch: [44/60]
# Training Loss: 602.9530, Accuracy: 84.71%
# NN saved.
# Epoch: [45/60]
# Training Loss: 612.5329, Accuracy: 85.54%
# NN saved.
# Epoch: [46/60]
# Training Loss: 616.7279, Accuracy: 84.61%
# NN saved.
# Epoch: [47/60]
# Training Loss: 586.2363, Accuracy: 85.34%
# NN saved.
# Epoch: [48/60]
# Training Loss: 597.5187, Accuracy: 85.29%
# NN saved.
# Epoch: [49/60]
# Training Loss: 590.7744, Accuracy: 84.95%
# NN saved.
# Epoch: [50/60]
# Training Loss: 597.2526, Accuracy: 84.66%
# NN saved.
# Epoch: [51/60]
# Training Loss: 608.0380, Accuracy: 85.15%
# NN saved.
# Epoch: [52/60]
# Training Loss: 600.2044, Accuracy: 84.46%
# NN saved.
# Epoch: [53/60]
# Training Loss: 548.9815, Accuracy: 86.13%
# NN saved.
# Epoch: [54/60]
# Training Loss: 577.2389, Accuracy: 84.90%
# NN saved.
# Epoch: [55/60]
# Training Loss: 536.7575, Accuracy: 86.37%
# NN saved.
# Epoch: [56/60]
# Training Loss: 556.5715, Accuracy: 85.93%
# NN saved.
# Epoch: [57/60]
# Training Loss: 485.3467, Accuracy: 87.65%
# NN saved.
# Epoch: [58/60]
# Training Loss: 518.8543, Accuracy: 86.67%
# NN saved.
# Epoch: [59/60]
# Training Loss: 541.7666, Accuracy: 86.42%
# NN saved.
# Epoch: [60/60]
# Training Loss: 523.7521, Accuracy: 86.03%
# NN saved.
# Training Complete in: 00h 18m 58s

# %%
# train_net_from_save(40)

# %%
# Test the CNN
test_net(net=cnn)
# Out:
# Test Accuracy: 30.41%

# %%
# Plot
import numpy as np
fig = plt.figure(tight_layout=True)
gs = grid.GridSpec(nrows=2, ncols=1)
ax_l = fig.add_subplot(gs[0, 0])
ax_l.set_xlabel("Epoch")
ax_l.set_ylabel("Loss")
ax_a = fig.add_subplot(gs[1, 0], sharex=ax_l)
ax_a.set_ylabel("Accuracy")

n_plots = len(learning_rate_testers)
colours = iter(plt.cm.rainbow(np.linspace(0, 1, n_plots)))


for lr_i in range(n_plots):
  t_losses = all_t_losses[lr_i]
  t_accs = all_t_accs[lr_i]
  lr = learning_rate_testers[lr_i]
  c = next(colours)
  ax_l.plot(t_losses[30::], label=str(lr), c=c)
  ax_a.plot(t_accs[30::], label=str(lr), c=c)

fig.legend(title="Learning rates", fontsize="small", loc=3, 
           labels=[str(i) for i in learning_rate_testers], bbox_to_anchor=(1, 0.5))
fig.align_labels()
plt.grid()
plt.show()
plt.savefig("figs/learning_rates.png")

# %%
# # Plot
# fig = plt.figure(tight_layout=True)
# gs = grid.GridSpec(nrows=2, ncols=1)

# def plot_epochs(ax, data: [[int]], ylabel: str, datalabels: [str], cs: [str]):
#     if len(datalabels) == len(data):
#         for line in range(len(data)):
#             ax.plot(data[line], label=datalabels[line], c=cs[line])
#         ax.set_xlabel("Epoch")
#         ax.set_ylabel(ylabel)
#         fig.align_labels()
#         plt.grid()
#         plt.legend()


# line_labels = ["Validation", "Training"]
# colours = ["forestgreen", "royalblue"]
# with open("./saves/save_data.txt", "r") as savefile:
#     savelist = savefile.readline().split("]")
#     v_losses, v_accs, t_losses, t_accs = [], [], [], []
#     # for vloss in savelist[0][1::].split(","):
#     #     v_losses.append(float(vloss.strip()))
#     # for vacc in savelist[1][1::].split(","):
#     #     v_accs.append(float(vacc.strip()))
#     for tloss in savelist[2][1::].split(","):
#         t_losses.append(float(tloss.strip()))
#     for tacc in savelist[3][1::].split(","):
#         t_accs.append(float(tacc.strip()))
#     epochs_done = int(savelist[4])
#     # for i in range(len(train_losses)):
#     #   t_losses[i]*=len(all_train_data)
#     plot_epochs(fig.add_subplot(gs[0, 0]), [v_accs, t_accs], "Accuracy", line_labels, colours)
#     plot_epochs(fig.add_subplot(gs[1, 0]), [v_losses, t_losses], "Loss", line_labels, colours)
#     plt.show()
#     fig.savefig("figs/training_graph.png")
