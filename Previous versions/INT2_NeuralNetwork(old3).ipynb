# %% [markdown]
# <a href="https://colab.research.google.com/github/INT2-group18/Network/blob/main/INT2_NeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import time
import gc

# Setup device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Training variables
BATCH_SIZE = 32
EPOCHS = 300
LEARNING_RATE = 0.00005

# Allowed transformations for the train, validation, and test datasets
train_transform = transforms.Compose([
    transforms.Resize(256, antialias=True),
    transforms.RandomCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_test_transform = transforms.Compose([
    transforms.Resize((256, 256), antialias=True),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load the train, validation, and test datasets
train_dataset = datasets.Flowers102(root="./data", split="train", transform=train_transform, download=True)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
val_dataset = datasets.Flowers102(root="./data", split="val", transform=val_test_transform, download=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
test_dataset = datasets.Flowers102(root="./data", split="test", transform=val_test_transform, download=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(16),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2, 2)) # 224 -> 112
        self.conv2 = nn.Sequential(nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(32),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2, 2)) # 112 -> 56
        self.conv3 = nn.Sequential(nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(64),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2, 2)) # 56 -> 28
        self.conv4 = nn.Sequential(nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(128),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2, 2)) # 28 -> 14
        self.conv5 = nn.Sequential(nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(256),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2, 2)) # 14 -> 7
        self.conv6 = nn.Sequential(nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(512),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2, 2)) # 7 -> 3
        self.conv7 = nn.Sequential(nn.Conv2d(512, 1024, kernel_size=3, stride=1, padding=1),
                                   nn.BatchNorm2d(1024),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2, 2)) # 3 -> 1

        self.fc1 = nn.Sequential(nn.Linear(1024, 512),
                                 nn.ReLU())
        self.fc2 = nn.Sequential(nn.Linear(512, 256),
                                 nn.ReLU())
        self.fc3 = nn.Sequential(nn.Linear(256, 102))

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = self.conv6(x)
        x = self.conv7(x)
        x = x.view(-1, 1024)
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        return x


# Clear CUDA cache
torch.cuda.empty_cache()

# Create an instance of the CNN and move it to the device
cnn = CNN().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cnn.parameters(), lr=LEARNING_RATE)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=10, factor=0.1, verbose=True)

# Train the CNN
for epoch in range(EPOCHS):
    cnn.train()
    train_loss = 0
    train_correct = 0
    train_total = 0
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)

        outputs = cnn(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

        if (i + 1) % 16 == 0:
            print(f"Epoch [{epoch + 1}/{EPOCHS}], Step [{i + 1}/{len(train_loader)}], Step Loss: {loss.item():.4f}")

    train_loss /= len(train_loader)
    train_accuracy = 100 * train_correct / train_total
    print(f'Epoch [{epoch+1}/{EPOCHS}], Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%')

    # Evaluate model after each training epoch
    cnn.eval()
    val_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = cnn(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_loss /= len(val_loader)
    accuracy = 100 * correct / total
    print(f'Epoch [{epoch+1}/{EPOCHS}], Validation Loss: {val_loss:.4f}, Validation Accuracy: {accuracy:.2f}%')

    # Update the learning rate scheduler
    scheduler.step(val_loss)

# Test the CNN on the test set
cnn.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = cnn(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_accuracy = 100 * correct / total
print(f'Test Accuracy: {test_accuracy:.2f}%')
# Out:
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/102flowers.tgz to data/flowers-102/102flowers.tgz
# 100%|██████████| 344862509/344862509 [00:11<00:00, 30907009.24it/s]
# Extracting data/flowers-102/102flowers.tgz to data/flowers-102
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/imagelabels.mat to data/flowers-102/imagelabels.mat
# 100%|██████████| 502/502 [00:00<00:00, 166012.82it/s]
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/setid.mat to data/flowers-102/setid.mat
# 100%|██████████| 14989/14989 [00:00<00:00, 15477208.93it/s]
# Epoch [1/300], Step [16/32], Step Loss: 4.6262
# Epoch [1/300], Step [32/32], Step Loss: 4.5337
# Epoch [1/300], Training Loss: 4.5872, Training Accuracy: 3.04%
# Epoch [1/300], Validation Loss: 4.5817, Validation Accuracy: 2.35%
# Epoch [2/300], Step [16/32], Step Loss: 4.4625
# Epoch [2/300], Step [32/32], Step Loss: 4.3375
# Epoch [2/300], Training Loss: 4.4075, Training Accuracy: 6.67%
# Epoch [2/300], Validation Loss: 4.3206, Validation Accuracy: 7.25%
# Epoch [3/300], Step [16/32], Step Loss: 4.2493
# Epoch [3/300], Step [32/32], Step Loss: 4.0804
# Epoch [3/300], Training Loss: 4.1927, Training Accuracy: 8.04%
# Epoch [3/300], Validation Loss: 4.0808, Validation Accuracy: 10.98%
# Epoch [4/300], Step [16/32], Step Loss: 3.7736
# Epoch [4/300], Step [32/32], Step Loss: 3.9041
# Epoch [4/300], Training Loss: 3.9188, Training Accuracy: 15.10%
# Epoch [4/300], Validation Loss: 3.8726, Validation Accuracy: 13.33%
# Epoch [5/300], Step [16/32], Step Loss: 3.7992
# Epoch [5/300], Step [32/32], Step Loss: 3.4583
# Epoch [5/300], Training Loss: 3.6654, Training Accuracy: 19.12%
# Epoch [5/300], Validation Loss: 3.6111, Validation Accuracy: 20.88%
# Epoch [6/300], Step [16/32], Step Loss: 3.3890
# Epoch [6/300], Step [32/32], Step Loss: 3.1997
# Epoch [6/300], Training Loss: 3.3947, Training Accuracy: 26.47%
# Epoch [6/300], Validation Loss: 3.4008, Validation Accuracy: 24.22%
# Epoch [7/300], Step [16/32], Step Loss: 2.9215
# Epoch [7/300], Step [32/32], Step Loss: 3.2362
# Epoch [7/300], Training Loss: 3.1451, Training Accuracy: 30.69%
# Epoch [7/300], Validation Loss: 3.2169, Validation Accuracy: 27.65%
# Epoch [8/300], Step [16/32], Step Loss: 3.2363
# Epoch [8/300], Step [32/32], Step Loss: 2.8680
# Epoch [8/300], Training Loss: 2.9072, Training Accuracy: 36.37%
# Epoch [8/300], Validation Loss: 3.0795, Validation Accuracy: 32.55%
# Epoch [9/300], Step [16/32], Step Loss: 2.5676
# Epoch [9/300], Step [32/32], Step Loss: 2.4613
# Epoch [9/300], Training Loss: 2.7023, Training Accuracy: 40.29%
# Epoch [9/300], Validation Loss: 2.9469, Validation Accuracy: 33.04%
# Epoch [10/300], Step [16/32], Step Loss: 2.4195
# Epoch [10/300], Step [32/32], Step Loss: 2.1038
# Epoch [10/300], Training Loss: 2.5322, Training Accuracy: 44.71%
# Epoch [10/300], Validation Loss: 2.8086, Validation Accuracy: 34.71%
# Epoch [11/300], Step [16/32], Step Loss: 2.3369
# Epoch [11/300], Step [32/32], Step Loss: 2.3781
# Epoch [11/300], Training Loss: 2.3411, Training Accuracy: 49.90%
# Epoch [11/300], Validation Loss: 2.7196, Validation Accuracy: 35.39%
# Epoch [12/300], Step [16/32], Step Loss: 2.4236
# Epoch [12/300], Step [32/32], Step Loss: 2.4340
# Epoch [12/300], Training Loss: 2.1715, Training Accuracy: 53.33%
# Epoch [12/300], Validation Loss: 2.7174, Validation Accuracy: 35.20%
# Epoch [13/300], Step [16/32], Step Loss: 2.0602
# Epoch [13/300], Step [32/32], Step Loss: 1.6889
# Epoch [13/300], Training Loss: 2.0177, Training Accuracy: 57.84%
# Epoch [13/300], Validation Loss: 2.5816, Validation Accuracy: 37.75%
# Epoch [14/300], Step [16/32], Step Loss: 1.5839
# Epoch [14/300], Step [32/32], Step Loss: 1.8623
# Epoch [14/300], Training Loss: 1.8677, Training Accuracy: 61.27%
# Epoch [14/300], Validation Loss: 2.4615, Validation Accuracy: 40.69%
# Epoch [15/300], Step [16/32], Step Loss: 1.6294
# Epoch [15/300], Step [32/32], Step Loss: 2.1036
# Epoch [15/300], Training Loss: 1.7411, Training Accuracy: 65.49%
# Epoch [15/300], Validation Loss: 2.4133, Validation Accuracy: 41.08%
# Epoch [16/300], Step [16/32], Step Loss: 1.5623
# Epoch [16/300], Step [32/32], Step Loss: 1.6117
# Epoch [16/300], Training Loss: 1.6336, Training Accuracy: 68.14%
# Epoch [16/300], Validation Loss: 2.3521, Validation Accuracy: 43.43%
# Epoch [17/300], Step [16/32], Step Loss: 1.6381
# Epoch [17/300], Step [32/32], Step Loss: 1.6528
# Epoch [17/300], Training Loss: 1.5298, Training Accuracy: 68.92%
# Epoch [17/300], Validation Loss: 2.3102, Validation Accuracy: 43.04%
# Epoch [18/300], Step [16/32], Step Loss: 1.4784
# Epoch [18/300], Step [32/32], Step Loss: 1.5677
# Epoch [18/300], Training Loss: 1.3910, Training Accuracy: 72.45%
# Epoch [18/300], Validation Loss: 2.2783, Validation Accuracy: 43.63%
# Epoch [19/300], Step [16/32], Step Loss: 1.2088
# Epoch [19/300], Step [32/32], Step Loss: 1.4780
# Epoch [19/300], Training Loss: 1.2673, Training Accuracy: 77.55%
# Epoch [19/300], Validation Loss: 2.2656, Validation Accuracy: 43.33%
# Epoch [20/300], Step [16/32], Step Loss: 1.0532
# Epoch [20/300], Step [32/32], Step Loss: 1.2271
# Epoch [20/300], Training Loss: 1.1573, Training Accuracy: 80.29%
# Epoch [21/300], Step [16/32], Step Loss: 1.1650
# Epoch [21/300], Step [32/32], Step Loss: 1.3401
# Epoch [21/300], Training Loss: 1.0591, Training Accuracy: 81.86%
# Epoch [21/300], Validation Loss: 2.1731, Validation Accuracy: 46.57%
# Epoch [22/300], Step [16/32], Step Loss: 1.0696
# Epoch [22/300], Step [32/32], Step Loss: 1.0144
# Epoch [22/300], Training Loss: 1.0016, Training Accuracy: 82.45%
# Epoch [22/300], Validation Loss: 2.1891, Validation Accuracy: 45.69%
# Epoch [23/300], Step [16/32], Step Loss: 1.0290
# Epoch [23/300], Step [32/32], Step Loss: 0.8864
# Epoch [23/300], Training Loss: 0.9018, Training Accuracy: 85.29%
# Epoch [23/300], Validation Loss: 2.1247, Validation Accuracy: 48.43%
# Epoch [24/300], Step [16/32], Step Loss: 0.7067
# Epoch [24/300], Step [32/32], Step Loss: 0.9531
# Epoch [24/300], Training Loss: 0.8060, Training Accuracy: 87.16%
# Epoch [24/300], Validation Loss: 2.1056, Validation Accuracy: 48.33%
# Epoch [25/300], Step [16/32], Step Loss: 0.7794
# Epoch [25/300], Step [32/32], Step Loss: 0.8649
# Epoch [25/300], Training Loss: 0.7229, Training Accuracy: 89.02%
# Epoch [25/300], Validation Loss: 2.1267, Validation Accuracy: 47.45%
# Epoch [26/300], Step [16/32], Step Loss: 0.7178
# Epoch [26/300], Step [32/32], Step Loss: 0.5422
# Epoch [26/300], Training Loss: 0.7334, Training Accuracy: 88.33%
# Epoch [26/300], Validation Loss: 2.0917, Validation Accuracy: 49.31%
# Epoch [27/300], Step [16/32], Step Loss: 0.4549
# Epoch [27/300], Validation Loss: 2.0637, Validation Accuracy: 50.49%
# Epoch [28/300], Step [16/32], Step Loss: 0.7174
# Epoch [28/300], Step [32/32], Step Loss: 0.6276
# Epoch [28/300], Training Loss: 0.5873, Training Accuracy: 91.96%
# Epoch [28/300], Validation Loss: 2.0896, Validation Accuracy: 49.02%
# Epoch [29/300], Step [16/32], Step Loss: 0.8442
# Epoch [29/300], Step [32/32], Step Loss: 0.7172
# Epoch [29/300], Training Loss: 0.5679, Training Accuracy: 92.25%
# Epoch [29/300], Validation Loss: 2.0402, Validation Accuracy: 47.55%
# Epoch [30/300], Step [16/32], Step Loss: 0.4119
# Epoch [30/300], Step [32/32], Step Loss: 0.6769
# Epoch [30/300], Training Loss: 0.4487, Training Accuracy: 94.71%
# Epoch [30/300], Validation Loss: 2.0735, Validation Accuracy: 47.75%
# Epoch [31/300], Step [16/32], Step Loss: 0.3719
# Epoch [31/300], Step [32/32], Step Loss: 0.6604
# Epoch [31/300], Training Loss: 0.4445, Training Accuracy: 95.49%
# Epoch [31/300], Validation Loss: 2.0634, Validation Accuracy: 48.63%
# Epoch [32/300], Step [16/32], Step Loss: 0.3692
# Epoch [32/300], Step [32/32], Step Loss: 0.2210
# Epoch [32/300], Training Loss: 0.3800, Training Accuracy: 96.47%
# Epoch [32/300], Validation Loss: 2.0348, Validation Accuracy: 50.29%
# Epoch [33/300], Step [16/32], Step Loss: 0.4275
# Epoch [33/300], Step [32/32], Step Loss: 0.4788
# Epoch [33/300], Training Loss: 0.3836, Training Accuracy: 95.39%
# Epoch [33/300], Validation Loss: 2.0844, Validation Accuracy: 48.04%
# Epoch [34/300], Step [16/32], Step Loss: 0.3373
# Epoch [34/300], Step [32/32], Step Loss: 0.2659
# Epoch [34/300], Training Loss: 0.3112, Training Accuracy: 98.04%
# Epoch [34/300], Validation Loss: 1.9844, Validation Accuracy: 52.45%
# Epoch [35/300], Step [16/32], Step Loss: 0.2920
# Epoch [35/300], Step [32/32], Step Loss: 0.3850
# Epoch [35/300], Training Loss: 0.3137, Training Accuracy: 96.37%
# Epoch [35/300], Validation Loss: 2.0613, Validation Accuracy: 51.27%
# Epoch [36/300], Step [16/32], Step Loss: 0.3315
# Epoch [36/300], Step [32/32], Step Loss: 0.2208
# Epoch [36/300], Training Loss: 0.3138, Training Accuracy: 96.47%
# Epoch [36/300], Validation Loss: 2.1209, Validation Accuracy: 48.43%
# Epoch [37/300], Step [16/32], Step Loss: 0.2673
# Epoch [37/300], Step [32/32], Step Loss: 0.3535
# Epoch [37/300], Training Loss: 0.2646, Training Accuracy: 97.75%
# Epoch [37/300], Validation Loss: 2.0818, Validation Accuracy: 50.10%
# Epoch [38/300], Step [16/32], Step Loss: 0.1500
# Epoch [38/300], Step [32/32], Step Loss: 0.3028
# Epoch [38/300], Training Loss: 0.2389, Training Accuracy: 97.75%
# Epoch [38/300], Validation Loss: 1.9978, Validation Accuracy: 51.47%
# Epoch [39/300], Step [16/32], Step Loss: 0.2165
# Epoch [39/300], Step [32/32], Step Loss: 0.2064
# Epoch [39/300], Training Loss: 0.1900, Training Accuracy: 98.82%
# Epoch [39/300], Validation Loss: 1.9648, Validation Accuracy: 53.33%
# Epoch [40/300], Step [16/32], Step Loss: 0.2215
# Epoch [40/300], Step [32/32], Step Loss: 0.1854
# Epoch [40/300], Training Loss: 0.2190, Training Accuracy: 97.55%
# Epoch [40/300], Validation Loss: 2.0649, Validation Accuracy: 50.59%
# Epoch [41/300], Step [16/32], Step Loss: 0.1336
# Epoch [41/300], Step [32/32], Step Loss: 0.1047
# Epoch [41/300], Training Loss: 0.1734, Training Accuracy: 99.31%
# Epoch [41/300], Validation Loss: 1.9592, Validation Accuracy: 52.75%
# Epoch [42/300], Step [16/32], Step Loss: 0.2111
# Epoch [42/300], Step [32/32], Step Loss: 0.0882
# Epoch [42/300], Training Loss: 0.1588, Training Accuracy: 99.02%
# Epoch [42/300], Validation Loss: 2.0126, Validation Accuracy: 51.27%
# Epoch [43/300], Step [16/32], Step Loss: 0.0875
# Epoch [43/300], Step [32/32], Step Loss: 0.1976
# Epoch [43/300], Training Loss: 0.1466, Training Accuracy: 99.12%
# Epoch [43/300], Validation Loss: 1.9294, Validation Accuracy: 53.14%
# Epoch [44/300], Step [16/32], Step Loss: 0.1035
# Epoch [44/300], Step [32/32], Step Loss: 0.1501
# Epoch [44/300], Training Loss: 0.1292, Training Accuracy: 99.41%
# Epoch [44/300], Validation Loss: 1.9581, Validation Accuracy: 53.63%
# Epoch [45/300], Step [16/32], Step Loss: 0.1246
# Epoch [45/300], Step [32/32], Step Loss: 0.1057
# Epoch [45/300], Training Loss: 0.1468, Training Accuracy: 99.02%
# Epoch [45/300], Validation Loss: 1.9825, Validation Accuracy: 51.47%
# Epoch [46/300], Step [16/32], Step Loss: 0.1557
# Epoch [46/300], Step [32/32], Step Loss: 0.1082
# Epoch [46/300], Training Loss: 0.1185, Training Accuracy: 99.31%
# Epoch [46/300], Validation Loss: 1.9892, Validation Accuracy: 52.65%
# Epoch [47/300], Step [16/32], Step Loss: 0.1515
# Epoch [47/300], Step [32/32], Step Loss: 0.1171
# Epoch [47/300], Training Loss: 0.1112, Training Accuracy: 99.12%
# Epoch [47/300], Validation Loss: 2.0373, Validation Accuracy: 52.06%
# Epoch [48/300], Step [16/32], Step Loss: 0.1387
# Epoch [48/300], Step [32/32], Step Loss: 0.0833
# Epoch [48/300], Training Loss: 0.1085, Training Accuracy: 99.31%
# Epoch [48/300], Validation Loss: 1.9512, Validation Accuracy: 55.00%
# Epoch [49/300], Step [16/32], Step Loss: 0.0869
# Epoch [49/300], Step [32/32], Step Loss: 0.1207
# Epoch [49/300], Training Loss: 0.0975, Training Accuracy: 99.61%
# Epoch [49/300], Validation Loss: 1.9522, Validation Accuracy: 52.25%
# Epoch [50/300], Step [16/32], Step Loss: 0.1068
# Epoch [50/300], Step [32/32], Step Loss: 0.1369
# Epoch [50/300], Training Loss: 0.0990, Training Accuracy: 99.31%
# Epoch [50/300], Validation Loss: 1.9330, Validation Accuracy: 53.43%
# Epoch [51/300], Step [16/32], Step Loss: 0.1236
# Epoch [51/300], Step [32/32], Step Loss: 0.0810
# Epoch [51/300], Training Loss: 0.0894, Training Accuracy: 99.71%
# Epoch [51/300], Validation Loss: 2.0201, Validation Accuracy: 51.76%
# Epoch [52/300], Step [16/32], Step Loss: 0.0925
# Epoch [52/300], Step [32/32], Step Loss: 0.0655
# Epoch [52/300], Training Loss: 0.0827, Training Accuracy: 99.90%
# Epoch [52/300], Validation Loss: 1.9638, Validation Accuracy: 53.73%
# Epoch [53/300], Step [16/32], Step Loss: 0.0555
# Epoch [53/300], Step [32/32], Step Loss: 0.0636
# Epoch [53/300], Training Loss: 0.0694, Training Accuracy: 99.90%
# Epoch [53/300], Validation Loss: 1.9505, Validation Accuracy: 53.33%
# Epoch [54/300], Step [16/32], Step Loss: 0.0604
# Epoch [54/300], Step [32/32], Step Loss: 0.0592
# Epoch [54/300], Training Loss: 0.0711, Training Accuracy: 99.51%
# Epoch [54/300], Validation Loss: 1.9240, Validation Accuracy: 53.33%
# Epoch [55/300], Step [16/32], Step Loss: 0.1457
# Epoch [55/300], Step [32/32], Step Loss: 0.0809
# Epoch [55/300], Training Loss: 0.0816, Training Accuracy: 99.31%
# Epoch [55/300], Validation Loss: 1.9733, Validation Accuracy: 54.12%
# Epoch [56/300], Step [16/32], Step Loss: 0.0490
# Epoch [56/300], Step [32/32], Step Loss: 0.0727
# Epoch [56/300], Training Loss: 0.0643, Training Accuracy: 99.90%
# Epoch [56/300], Validation Loss: 2.0627, Validation Accuracy: 51.96%
# Epoch [57/300], Step [16/32], Step Loss: 0.0860
# Epoch [57/300], Step [32/32], Step Loss: 0.0452
# Epoch [57/300], Training Loss: 0.0643, Training Accuracy: 99.90%
# Epoch [57/300], Validation Loss: 1.9503, Validation Accuracy: 53.04%
# Epoch [58/300], Step [16/32], Step Loss: 0.0612
# Epoch [58/300], Step [32/32], Step Loss: 0.0853
# Epoch [58/300], Training Loss: 0.0622, Training Accuracy: 99.80%
# Epoch [58/300], Validation Loss: 1.9703, Validation Accuracy: 53.53%
# Epoch [59/300], Step [16/32], Step Loss: 0.0394
# Epoch [59/300], Step [32/32], Step Loss: 0.0390
# Epoch [59/300], Training Loss: 0.0516, Training Accuracy: 99.90%
# Epoch [59/300], Validation Loss: 1.9554, Validation Accuracy: 53.63%
# Epoch [60/300], Step [16/32], Step Loss: 0.0455
# Epoch [60/300], Step [32/32], Step Loss: 0.0542
# Epoch [60/300], Training Loss: 0.0529, Training Accuracy: 99.90%
# Epoch [60/300], Validation Loss: 1.9474, Validation Accuracy: 54.02%
# Epoch [61/300], Step [16/32], Step Loss: 0.0268
# Epoch [61/300], Step [32/32], Step Loss: 0.0633
# Epoch [61/300], Training Loss: 0.0484, Training Accuracy: 100.00%
# Epoch [61/300], Validation Loss: 1.9481, Validation Accuracy: 54.22%
# Epoch [62/300], Step [16/32], Step Loss: 0.0399
# Epoch [62/300], Step [32/32], Step Loss: 0.2120
# Epoch [62/300], Training Loss: 0.0637, Training Accuracy: 99.51%
# Epoch [62/300], Validation Loss: 1.9725, Validation Accuracy: 54.31%
# Epoch [63/300], Step [16/32], Step Loss: 0.0562
# Epoch [63/300], Step [32/32], Step Loss: 0.0441
# Epoch [63/300], Training Loss: 0.0559, Training Accuracy: 99.90%
# Epoch [63/300], Validation Loss: 1.9707, Validation Accuracy: 53.92%
# Epoch [64/300], Step [16/32], Step Loss: 0.0337
# Epoch [64/300], Step [32/32], Step Loss: 0.0244
# Epoch [64/300], Training Loss: 0.0398, Training Accuracy: 99.80%
# Epoch [64/300], Validation Loss: 1.9341, Validation Accuracy: 55.69%
# Epoch [65/300], Step [16/32], Step Loss: 0.0198
# Epoch [65/300], Step [32/32], Step Loss: 0.0255
# Epoch [65/300], Training Loss: 0.0498, Training Accuracy: 99.61%
# Epoch [65/300], Validation Loss: 2.0460, Validation Accuracy: 53.24%
# Epoch 00065: reducing learning rate of group 0 to 5.0000e-06.
# Epoch [66/300], Step [16/32], Step Loss: 0.0418
# Epoch [66/300], Step [32/32], Step Loss: 0.0619
# Epoch [66/300], Training Loss: 0.0506, Training Accuracy: 99.80%
# Epoch [66/300], Validation Loss: 1.9109, Validation Accuracy: 55.59%
# Epoch [67/300], Step [16/32], Step Loss: 0.0357
# Epoch [67/300], Step [32/32], Step Loss: 0.0218
# Epoch [67/300], Training Loss: 0.0334, Training Accuracy: 99.80%
# Epoch [67/300], Validation Loss: 1.8938, Validation Accuracy: 56.47%
# Epoch [68/300], Step [16/32], Step Loss: 0.0330
# Epoch [68/300], Step [32/32], Step Loss: 0.0359
# Epoch [68/300], Training Loss: 0.0362, Training Accuracy: 99.90%
# Epoch [68/300], Validation Loss: 1.8868, Validation Accuracy: 56.67%
# Epoch [69/300], Step [16/32], Step Loss: 0.0172
# Epoch [69/300], Step [32/32], Step Loss: 0.0344
# Epoch [69/300], Training Loss: 0.0303, Training Accuracy: 100.00%
# Epoch [69/300], Validation Loss: 1.8804, Validation Accuracy: 56.86%
# Epoch [70/300], Step [16/32], Step Loss: 0.0183
# Epoch [70/300], Step [32/32], Step Loss: 0.0406
# Epoch [70/300], Training Loss: 0.0273, Training Accuracy: 100.00%
# Epoch [70/300], Validation Loss: 1.8931, Validation Accuracy: 56.18%
# Epoch [71/300], Step [16/32], Step Loss: 0.0148
# Epoch [71/300], Step [32/32], Step Loss: 0.0302
# Epoch [71/300], Training Loss: 0.0265, Training Accuracy: 100.00%
# Epoch [71/300], Validation Loss: 1.8808, Validation Accuracy: 56.86%
# Epoch [72/300], Step [16/32], Step Loss: 0.0275
# Epoch [72/300], Step [32/32], Step Loss: 0.0203
# Epoch [72/300], Training Loss: 0.0260, Training Accuracy: 99.90%
# Epoch [72/300], Validation Loss: 1.8909, Validation Accuracy: 56.96%
# Epoch [73/300], Step [16/32], Step Loss: 0.0209
# Epoch [73/300], Step [32/32], Step Loss: 0.0219
# Epoch [73/300], Training Loss: 0.0275, Training Accuracy: 100.00%
# Epoch [73/300], Validation Loss: 1.8837, Validation Accuracy: 56.47%
# Epoch [74/300], Step [16/32], Step Loss: 0.0159
# Epoch [74/300], Step [32/32], Step Loss: 0.0184
# Epoch [74/300], Training Loss: 0.0220, Training Accuracy: 100.00%
# Epoch [74/300], Validation Loss: 1.8907, Validation Accuracy: 56.37%
# Epoch [75/300], Step [16/32], Step Loss: 0.0132
# Epoch [75/300], Step [32/32], Step Loss: 0.0194
# Epoch [75/300], Training Loss: 0.0261, Training Accuracy: 100.00%
# Epoch [75/300], Validation Loss: 1.8854, Validation Accuracy: 56.37%
# Epoch [76/300], Step [16/32], Step Loss: 0.0185
# Epoch [76/300], Step [32/32], Step Loss: 0.0118
# Epoch [76/300], Training Loss: 0.0243, Training Accuracy: 100.00%
# Epoch [76/300], Validation Loss: 1.8901, Validation Accuracy: 56.76%
# Epoch [77/300], Step [16/32], Step Loss: 0.0172
# Epoch [77/300], Step [32/32], Step Loss: 0.0381
# Epoch [77/300], Training Loss: 0.0224, Training Accuracy: 100.00%
# Epoch [77/300], Validation Loss: 1.8954, Validation Accuracy: 56.08%
# Epoch [78/300], Step [16/32], Step Loss: 0.0178
# Epoch [78/300], Step [32/32], Step Loss: 0.0294
# Epoch [78/300], Training Loss: 0.0255, Training Accuracy: 99.90%
# Epoch [78/300], Validation Loss: 1.8788, Validation Accuracy: 56.57%
# Epoch [79/300], Step [16/32], Step Loss: 0.0237
# Epoch [79/300], Step [32/32], Step Loss: 0.0390
# Epoch [79/300], Training Loss: 0.0277, Training Accuracy: 100.00%
# Epoch [79/300], Validation Loss: 1.8791, Validation Accuracy: 56.47%
# Epoch [80/300], Step [16/32], Step Loss: 0.0293
# Epoch [80/300], Step [32/32], Step Loss: 0.0495
# Epoch [80/300], Training Loss: 0.0240, Training Accuracy: 99.80%
# Epoch [80/300], Validation Loss: 1.8822, Validation Accuracy: 56.08%
# Epoch [81/300], Step [16/32], Step Loss: 0.0309
# Epoch [81/300], Step [32/32], Step Loss: 0.0324
# Epoch [81/300], Training Loss: 0.0249, Training Accuracy: 100.00%
# Epoch [81/300], Validation Loss: 1.9003, Validation Accuracy: 56.47%
# Epoch [82/300], Step [16/32], Step Loss: 0.0179
# Epoch [82/300], Step [32/32], Step Loss: 0.0329
# Epoch [82/300], Training Loss: 0.0258, Training Accuracy: 99.90%
# Epoch [82/300], Validation Loss: 1.8929, Validation Accuracy: 56.47%
# Epoch [83/300], Step [16/32], Step Loss: 0.0293
# Epoch [83/300], Step [32/32], Step Loss: 0.0181
# Epoch [83/300], Training Loss: 0.0259, Training Accuracy: 100.00%
# Epoch [83/300], Validation Loss: 1.8862, Validation Accuracy: 56.67%
# Epoch [84/300], Step [16/32], Step Loss: 0.0620
# Epoch [84/300], Step [32/32], Step Loss: 0.0222
# Epoch [84/300], Training Loss: 0.0245, Training Accuracy: 100.00%
# Epoch [84/300], Validation Loss: 1.8901, Validation Accuracy: 56.18%
# Epoch [85/300], Step [16/32], Step Loss: 0.0326
# Epoch [85/300], Step [32/32], Step Loss: 0.0345
# Epoch [85/300], Training Loss: 0.0256, Training Accuracy: 100.00%
# Epoch [85/300], Validation Loss: 1.9001, Validation Accuracy: 56.47%
# Epoch [86/300], Step [16/32], Step Loss: 0.0228
# Epoch [86/300], Step [32/32], Step Loss: 0.0297
# Epoch [86/300], Training Loss: 0.0214, Training Accuracy: 100.00%
# Epoch [86/300], Validation Loss: 1.8854, Validation Accuracy: 56.27%
# Epoch [87/300], Step [16/32], Step Loss: 0.0153
# Epoch [87/300], Step [32/32], Step Loss: 0.0140
# Epoch [87/300], Training Loss: 0.0216, Training Accuracy: 100.00%
# Epoch [87/300], Validation Loss: 1.8951, Validation Accuracy: 55.98%
# Epoch [88/300], Step [16/32], Step Loss: 0.0118
# Epoch [88/300], Step [32/32], Step Loss: 0.0246
# Epoch [88/300], Training Loss: 0.0204, Training Accuracy: 100.00%
# Epoch [88/300], Validation Loss: 1.8821, Validation Accuracy: 57.16%
# Epoch [89/300], Step [16/32], Step Loss: 0.0120
